# %%
#pip install citipy

# %%
from citipy import citipy
from random import uniform
import requests, json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

# %%
city = citipy.nearest_city(22.99, 120.21)


#city.city_name     # Tainan, my home town
#'tainan'

#city.country_code
#'tw'                  # And the country is surely Taiwan

# %%
cities = []
lats_random = []
for i in range(20):
    lat_coord  = round(uniform(-180,180), 2)
    long_coord = round(uniform(-90, 90), 2)
    city = citipy.nearest_city(lat_coord, long_coord).city_name
    cities.append(city)
    lats_random.append(lat_coord)
    print(f"{city}, located at ({lat_coord}, {long_coord})")
print (cities, lats)
# Out:
# qaanaaq, located at (162.67, -88.78)
# antofagasta, located at (-24.53, -68.71)
# ushuaia, located at (-165.6, -18.29)
# sakakah, located at (30.5, 40.55)
# port elizabeth, located at (-132.44, 50.18)
# albany, located at (-172.42, 71.5)
# ushuaia, located at (-124.43, -15.22)
# skjervoy, located at (70.02, 21.22)
# qaanaaq, located at (95.61, -72.91)
# barentsburg, located at (111.65, 9.8)
# ponta delgada, located at (33.73, -28.17)
# dikson, located at (157.48, 79.3)
# kruisfontein, located at (-128.35, 33.81)
# qaanaaq, located at (109.4, -61.11)
# ushuaia, located at (-53.39, -65.24)
# alibag, located at (18.61, 72.01)
# geraldton, located at (54.21, -87.82)
# albany, located at (-154.28, 74.15)
# ushuaia, located at (-96.89, -29.08)
# bourg-en-bresse, located at (46.39, 5.23)
# ...

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = 'dd74909c8156c984d600e5782436601a'
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info

lats = []
temps = []
humids = []
cloudies = []
wind_speeds = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        lat = response['coord']['lat']
        temp = round(response['main']['temp'])
        humid = response['main']['humidity']
        cloud = response['clouds']['all']
        wind = response['wind']['speed']
    except KeyError:
        temp = np.nan
        humid = np.nan
        cloud = np.nan
        wind = np.nan
    lats.append(lat)
    temps.append(temp)
    humids.append(humid)
    cloudies.append(cloud)
    wind_speeds.append(wind)
    print (f"{city} latitude is {lat}, temp is {temp}, humidity i {humid}, cloudiness is {cloud}, wind speed is {wind}")
#print (response)
# Out:
# qaanaaq latitude is 77.484, temp is -10, humidity i 70, cloudiness is 100, wind speed is 3.95
# antofagasta latitude is -23.65, temp is 18, humidity i 68, cloudiness is 20, wind speed is 6.17
# ushuaia latitude is -54.8, temp is 11, humidity i 43, cloudiness is 0, wind speed is 0.79
# sakakah latitude is 29.9697, temp is 34, humidity i 10, cloudiness is 75, wind speed is 6.69
# port elizabeth latitude is -33.918, temp is 20, humidity i 88, cloudiness is 40, wind speed is 4.63
# albany latitude is 42.6001, temp is 7, humidity i 87, cloudiness is 99, wind speed is 0.89
# ushuaia latitude is -54.8, temp is 11, humidity i 43, cloudiness is 0, wind speed is 0.62
# skjervoy latitude is 70.0311, temp is 2, humidity i 87, cloudiness is 75, wind speed is 12
# qaanaaq latitude is 77.484, temp is -10, humidity i 71, cloudiness is 100, wind speed is 4.06
# barentsburg latitude is 77.484, temp is nan, humidity i nan, cloudiness is nan, wind speed is nan
# ...

# %%
lat_vs_temp_df = pd.DataFrame({"City" : cities,
                             "Latitude": lats,
                               "Degrees From Equator": list(map(abs, lats)),
                               "Temperature" : temps,
                               "Humidity" : humids,
                               "Cloudiness" : cloudies,
                               "Wind Speed" : wind_speeds
                              })
lat_vs_temp_df
# Out:
#                City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0           qaanaaq   77.4840               77.4840        -10.0      70.0
# 1       antofagasta  -23.6500               23.6500         18.0      68.0
# 2           ushuaia  -54.8000               54.8000         11.0      43.0
# 3           sakakah   29.9697               29.9697         34.0      10.0
# 4    port elizabeth  -33.9180               33.9180         20.0      88.0
# 5            albany   42.6001               42.6001          7.0      87.0
# 6           ushuaia  -54.8000               54.8000         11.0      43.0
# 7          skjervoy   70.0311               70.0311          2.0      87.0
# 8           qaanaaq   77.4840               77.4840        -10.0      71.0
# 9       barentsburg   77.4840               77.4840          NaN       NaN
# 10    ponta delgada   37.7333               37.7333         17.0      94.0
# ...

# %%
clean_lat_vs_temp_df = lat_vs_temp_df.dropna(how='any', axis=0)

clean_lat_vs_temp_df= clean_lat_vs_temp_df.drop_duplicates(subset ="City",
                     keep = 'first').reset_index(drop=True)

#clean_lat_vs_temp_df = clean_lat_vs_temp_df

clean_lat_vs_temp_df
# Out:
#                City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0           qaanaaq   77.4840               77.4840        -10.0      70.0
# 1       antofagasta  -23.6500               23.6500         18.0      68.0
# 2           ushuaia  -54.8000               54.8000         11.0      43.0
# 3           sakakah   29.9697               29.9697         34.0      10.0
# 4    port elizabeth  -33.9180               33.9180         20.0      88.0
# 5            albany   42.6001               42.6001          7.0      87.0
# 6          skjervoy   70.0311               70.0311          2.0      87.0
# 7     ponta delgada   37.7333               37.7333         17.0      94.0
# 8            dikson   73.5069               73.5069         -1.0      93.0
# 9      kruisfontein  -34.0033               34.0033         18.0      92.0
# 10           alibag   18.6411               18.6411         29.0      79.0
# ...

# %%
ax1 = clean_lat_vs_temp_df.plot.scatter(x='Temperature', y='Degrees From Equator', c='DarkBlue')
plt.show()


#plt.scatter(clean_lat_vs_temp_df["temps, lats, marker="o", facecolors="red", edgecolors="black", s=temps, alpha=1)

# %%
temps_to_plot = clean_lat_vs_temp_df["Temperature"]
lats_to_plot = clean_lat_vs_temp_df["Degrees From Equator"]

slope, intercept, rvalue, pvalue, stderr = stats.linregress(temps_to_plot, lats_to_plot)  # Get elements of regression equation

regress_values = temps_to_plot * slope + intercept       # Create regression equation"
# Out:
# 0     78.559316
# 1     37.782598
# 2     47.976778
# 3     14.481616
# 4     34.869975
# 5     53.802023
# 6     61.083580
# 7     39.238909
# 8     65.452514
# 9     37.782598
# 10    21.763173
# 11    34.869975
# 12    43.607844
# Name: Temperature, dtype: float64

# %%
temps_for_r = [temp + 273.15 for temp in temps_to_plot]
temps_for_r
# Out:
# [263.15,
#  291.15,
#  284.15,
#  307.15,
#  293.15,
#  280.15,
#  275.15,
#  290.15,
#  272.15,
#  291.15,
#  302.15,
#  293.15,
#  287.15]

# %%
print(f"Correlation coefficient between Temperature and Degrees from equator: {round(stats.pearsonr(temps_for_r, lats_to_plot)[0],2)}")

plt.scatter(temps_to_plot, lats_to_plot, marker="o", facecolors="darkred",  alpha=1)


line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.annotate(line_eq,(-10,20),fontsize=15, color="steelblue")                # regression equation on the chart

plt.plot(temps_to_plot, regress_values, color="steelblue")

plt.show()
# Out:
# Correlation coefficient between Temperature and Degrees from equator: -0.9
