# %%
from citipy import citipy
from random import uniform
import requests, json
from config import api_key
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

pd.options.display.float_format = '{:,.2f}'.format # Set number formatting for all dataframes

# %%
# Generate list of cities based on randomly selected latitudes and longitudes

cities = []                                                       # Create empty list

for i in range(1, 1200):                                          # Note that I limit the latitude range a little.
    lat_coord  = round(uniform(-60,75), 2)                        # Antarctica and deep arctic aren't very useful and                     
    long_coord = round(uniform(-180, 180), 2)                     # skew the results
    
    city = citipy.nearest_city(lat_coord, long_coord).city_name   # Use Citipy to get name of city nearest the randomly
    cities.append(city)                                           # generated coordinates

# %%
# Remove duplicates from list of cities

initial_city_list_df = pd.DataFrame({"Cities" : cities})           # Create initial dataframe

clean_initial_city_list_df = initial_city_list_df.drop_duplicates(subset ="Cities",     
                     keep = 'first').reset_index(drop=True)        # Drop duplicates and reset index
clean_initial_city_list_df
# Out:
#              Cities
# 0            albany
# 1          bilibino
# 2              hilo
# 3    ribeira grande
# 4        nikolskoye
# ..              ...
# 638      kautokeino
# 639            amga
# 640            vila
# 641        yar-sale
# 642       yongchang
#
# [643 rows x 1 columns]

# %%
# Get weather data from OpenWeather API

url = "http://api.openweathermap.org/data/2.5/weather?"        # Base url
units = "metric"                                               # Set units to request

query_url = f"{url}appid={api_key}&units={units}&q="           # Build the query URL

lats = []                                                      # Set up lists to hold reponse info
temps = []
humids = []
cloudies = []
wind_speeds = []

i = 1                                                          # Start a counter so that the print includes count

for city in clean_initial_city_list_df['Cities']:              # Loop through the list of cities 
                                                               # and perform a request for data on each
    response = requests.get(query_url + city).json()           # Get response and convert to json
    
    try:
        lat = response['coord']['lat']                         # Not all cities found in Citipy have data in 
        temp = round(response['main']['temp'])                 # OpenWeather. So this 'try' block will look for
        humid = response['main']['humidity']                   # the data and set the respective variables... 
        cloud = response['clouds']['all']
        wind = response['wind']['speed']
    
    except KeyError:                                           # ...And this 'except' block will set variables to 
        lat = np.nan                                           # np.nan for those cities that lack data. That way the
        temp = np.nan                                          # program won't blow up and later it will be easy to                                          
        humid = np.nan                                         # drop rows with missing data.  
        cloud = np.nan
        wind = np.nan
    
    lats.append(lat)                                           # Append data to respective lists
    temps.append(temp)
    humids.append(humid)
    cloudies.append(cloud)
    wind_speeds.append(wind)
    
    # Print the data being processed
    print (f"{i}: {city} lat: {lat}, temp: {temp}, humidity: {humid}, cloudiness: {cloud}, wind speed: {wind}")
    i+=1
# Out:
# 1: albany lat: 42.6001, temp: 5, humidity: 34, cloudiness: 86, wind speed: 6.42
# 2: bilibino lat: 68.0546, temp: -6, humidity: 84, cloudiness: 98, wind speed: 1.5
# 3: hilo lat: 19.7297, temp: 25, humidity: 51, cloudiness: 75, wind speed: 3.6
# 4: ribeira grande lat: 38.5167, temp: 14, humidity: 78, cloudiness: 60, wind speed: 16.78
# 5: nikolskoye lat: 59.7035, temp: 7, humidity: 93, cloudiness: 90, wind speed: 1
# 6: leningradskiy lat: 69.3833, temp: 1, humidity: 74, cloudiness: 90, wind speed: 0.91
# 7: atuona lat: -9.8, temp: 27, humidity: 75, cloudiness: 53, wind speed: 9.17
# 8: laguna lat: 38.421, temp: 22, humidity: 43, cloudiness: 1, wind speed: 5.14
# 9: faya lat: 18.3851, temp: 18, humidity: 48, cloudiness: 0, wind speed: 1.54
# 10: vaini lat: -21.2, temp: 29, humidity: 84, cloudiness: 40, wind speed: 2.57
# 11: tuatapere lat: -46.1333, temp: 9, humidity: 98, cloudiness: 99, wind speed: 3.13
# 12: viedma lat: -40.8135, temp: 17, humidity: 55, cloudiness: 42, wind speed: 2.24
# 13: palimbang lat: 6.2106, temp: 26, humidity: 82, cloudiness: 22, wind speed: 1.28
# 14: christchurch lat: -43.5333, temp: 17, humidity: 67, cloudiness: 88, wind speed: 1.54
# 15: esperance lat: -33.8667, temp: 12, humidity: 94, cloudiness: 99, wind speed: 3.6
# 16: asau lat: 46.4333, temp: 8, humidity: 53, cloudiness: 100, wind speed: 2.14
# 17: hamilton lat: 39.1834, temp: 11, humidity: 32, cloudiness: 40, wind speed: 5.66
# 18: yulara lat: -25.2406, temp: 13, humidity: 67, cloudiness: 0, wind speed: 3.09
# 19: hasaki lat: 35.7333, temp: 9, humidity: 66, cloudiness: 20, wind speed: 6.17
# 20: taolanaro lat: 35.7333, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 21: touros lat: -5.1989, temp: 27, humidity: 78, cloudiness: 40, wind speed: 5.14
# 22: nome lat: 64.5011, temp: 6, humidity: 49, cloudiness: 1, wind speed: 3.09
# 23: illoqqortoormiut lat: 64.5011, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 24: mataura lat: -46.1927, temp: 9, humidity: 98, cloudiness: 97, wind speed: 3.13
# 25: hambantota lat: 6.1241, temp: 26, humidity: 100, cloudiness: 40, wind speed: 1.54
# 26: rungata lat: 6.1241, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 27: collie lat: -33.3667, temp: 11, humidity: 85, cloudiness: 89, wind speed: 2.03
# 28: jamestown lat: 42.097, temp: 0, humidity: 93, cloudiness: 90, wind speed: 7.72
# 29: nampula lat: -15.1165, temp: 22, humidity: 94, cloudiness: 75, wind speed: 5.14
# 30: rikitea lat: -23.1203, temp: 26, humidity: 75, cloudiness: 81, wind speed: 7.3
# 31: victoria lat: 22.2855, temp: 23, humidity: 83, cloudiness: 0, wind speed: 2.26
# 32: petropavlovsk-kamchatskiy lat: 53.0452, temp: 4, humidity: 75, cloudiness: 20, wind speed: 3
# 33: hovd lat: 48.0056, temp: 0, humidity: 32, cloudiness: 100, wind speed: 2.04
# 34: verkhnetulomskiy lat: 68.6073, temp: 1, humidity: 93, cloudiness: 75, wind speed: 3
# 35: lorengau lat: -2.0226, temp: 28, humidity: 78, cloudiness: 100, wind speed: 1.78
# 36: nizhniy kuranakh lat: 58.8353, temp: -6, humidity: 84, cloudiness: 90, wind speed: 3.06
# 37: turukhansk lat: 65.8167, temp: -2, humidity: 94, cloudiness: 100, wind speed: 5.23
# 38: hannibal lat: 39.7084, temp: 14, humidity: 21, cloudiness: 1, wind speed: 2.06
# 39: sorong lat: -0.8833, temp: 26, humidity: 87, cloudiness: 82, wind speed: 1.95
# 40: brindisi lat: 40.5833, temp: 14, humidity: 98, cloudiness: 100, wind speed: 1.34
# 41: lavrentiya lat: 65.5833, temp: 0, humidity: 65, cloudiness: 89, wind speed: 0.41
# 42: egvekinot lat: 66.3167, temp: -2, humidity: 68, cloudiness: 6, wind speed: 0.94
# 43: corinth lat: 37.9407, temp: 13, humidity: 55, cloudiness: 83, wind speed: 0.45
# 44: caravelas lat: -17.7125, temp: 24, humidity: 82, cloudiness: 93, wind speed: 2.75
# 45: bengkulu lat: -3.8004, temp: 23, humidity: 88, cloudiness: 82, wind speed: 1.91
# 46: kapaa lat: 22.0752, temp: 26, humidity: 69, cloudiness: 20, wind speed: 5.14
# 47: camapua lat: -19.5314, temp: 25, humidity: 31, cloudiness: 0, wind speed: 0.97
# 48: katangli lat: 51.7102, temp: 4, humidity: 78, cloudiness: 78, wind speed: 4.17
# 49: muros lat: 42.7762, temp: 12, humidity: 86, cloudiness: 82, wind speed: 2.86
# 50: coruripe lat: -10.1256, temp: 26, humidity: 84, cloudiness: 45, wind speed: 5.15
# 51: balabac lat: 7.9868, temp: 27, humidity: 83, cloudiness: 100, wind speed: 4.66
# 52: lethem lat: 3.3803, temp: 31, humidity: 66, cloudiness: 40, wind speed: 6.17
# 53: mehkar lat: 20.1508, temp: 28, humidity: 20, cloudiness: 83, wind speed: 2.31
# 54: klaksvik lat: 62.2266, temp: 6, humidity: 81, cloudiness: 75, wind speed: 2.69
# 55: chuy lat: -33.6971, temp: 19, humidity: 79, cloudiness: 10, wind speed: 5.43
# 56: hualmay lat: -11.0964, temp: 21, humidity: 80, cloudiness: 19, wind speed: 3.92
# 57: barrow lat: 71.2906, temp: -7, humidity: 79, cloudiness: 1, wind speed: 2.57
# 58: hirtshals lat: 57.5881, temp: 6, humidity: 70, cloudiness: 8, wind speed: 2.57
# 59: atessa lat: 42.0693, temp: 10, humidity: 82, cloudiness: 86, wind speed: 0.45
# 60: kaitangata lat: -46.2817, temp: 13, humidity: 89, cloudiness: 100, wind speed: 1.79
# 61: lebu lat: -37.6167, temp: 12, humidity: 71, cloudiness: 86, wind speed: 1.4
# 62: kungurtug lat: 50.5994, temp: -3, humidity: 88, cloudiness: 100, wind speed: 0.89
# 63: galesong lat: -5.3166, temp: 22, humidity: 100, cloudiness: 20, wind speed: 1.54
# 64: bandar-e lengeh lat: 26.5579, temp: 26, humidity: 69, cloudiness: 9, wind speed: 2.06
# 65: belmonte lat: -15.8631, temp: 25, humidity: 78, cloudiness: 0, wind speed: 3.09
# 66: ponta do sol lat: 32.6667, temp: 17, humidity: 89, cloudiness: 82, wind speed: 2.24
# 67: punta arenas lat: -53.15, temp: 9, humidity: 87, cloudiness: 75, wind speed: 3.09
# 68: portland lat: 45.5234, temp: 17, humidity: 51, cloudiness: 40, wind speed: 3.09
# 69: georgetown lat: 5.4112, temp: 25, humidity: 94, cloudiness: 40, wind speed: 1.03
# 70: guayata lat: 4.9642, temp: 19, humidity: 88, cloudiness: 95, wind speed: 1.48
# 71: dichiseni lat: 44.2333, temp: 14, humidity: 39, cloudiness: 83, wind speed: 0.89
# 72: shingu lat: 33.7333, temp: 15, humidity: 77, cloudiness: 86, wind speed: 4.01
# 73: highland lat: 34.1283, temp: 15, humidity: 48, cloudiness: 90, wind speed: 2.06
# 74: half moon bay lat: 37.4636, temp: 14, humidity: 93, cloudiness: 90, wind speed: 2.57
# 75: ilulissat lat: 69.2167, temp: -2, humidity: 69, cloudiness: 100, wind speed: 3.09
# 76: arman lat: 59.7, temp: -1, humidity: 96, cloudiness: 100, wind speed: 1.89
# 77: hohhot lat: 40.8106, temp: 9, humidity: 81, cloudiness: 0, wind speed: 1
# 78: artyk lat: 40.8106, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 79: bredasdorp lat: -34.5322, temp: 13, humidity: 94, cloudiness: 2, wind speed: 1.54
# 80: samandag lat: 36.0842, temp: 16, humidity: 82, cloudiness: 0, wind speed: 8.23
# 81: karaul lat: 36.0842, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 82: dunedin lat: -45.8742, temp: 14, humidity: 86, cloudiness: 99, wind speed: 0.45
# 83: puerto ayora lat: -0.7393, temp: 27, humidity: 69, cloudiness: 20, wind speed: 8.75
# 84: tasiilaq lat: 65.6145, temp: -1, humidity: 55, cloudiness: 75, wind speed: 7.2
# 85: aykhal lat: 66, temp: -5, humidity: 94, cloudiness: 99, wind speed: 11.52
# 86: sitka lat: 57.0531, temp: 10, humidity: 50, cloudiness: 1, wind speed: 3.6
# 87: kintampo lat: 8.0563, temp: 26, humidity: 60, cloudiness: 99, wind speed: 1.42
# 88: hithadhoo lat: -0.6, temp: 28, humidity: 73, cloudiness: 44, wind speed: 3.39
# 89: nynashamn lat: 58.9034, temp: 1, humidity: 89, cloudiness: 100, wind speed: 1.79
# 90: brewster lat: 41.3973, temp: 6, humidity: 34, cloudiness: 75, wind speed: 5.66
# 91: bereznik lat: 62.8551, temp: 4, humidity: 87, cloudiness: 97, wind speed: 2.83
# 92: thompson lat: 55.7435, temp: -6, humidity: 79, cloudiness: 75, wind speed: 8.23
# 93: loreto lat: 22.2667, temp: 28, humidity: 9, cloudiness: 71, wind speed: 8.68
# 94: samusu lat: 22.2667, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 95: paita lat: -5.0892, temp: 28, humidity: 57, cloudiness: 0, wind speed: 8.75
# 96: imeni telmana lat: -5.0892, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 97: balikpapan lat: -1.2675, temp: 24, humidity: 88, cloudiness: 99, wind speed: 2.55
# 98: sri aman lat: 1.2376, temp: 23, humidity: 94, cloudiness: 85, wind speed: 0.37
# 99: iqaluit lat: 63.7506, temp: -5, humidity: 74, cloudiness: 90, wind speed: 2.57
# 100: sangar lat: 63.9242, temp: -13, humidity: 93, cloudiness: 85, wind speed: 2.48
# 101: fortuna lat: 40.5982, temp: 13, humidity: 87, cloudiness: 40, wind speed: 6.69
# 102: brekstad lat: 63.687, temp: 2, humidity: 87, cloudiness: 75, wind speed: 7.72
# 103: butaritari lat: 3.0707, temp: 28, humidity: 74, cloudiness: 49, wind speed: 5.03
# 104: barkhan lat: 29.8977, temp: 22, humidity: 27, cloudiness: 0, wind speed: 1.62
# 105: ntungamo lat: -0.8833, temp: 17, humidity: 88, cloudiness: 47, wind speed: 1.44
# 106: revelstoke lat: 50.9832, temp: 12, humidity: 43, cloudiness: 90, wind speed: 2.57
# 107: padang lat: -0.9492, temp: 24, humidity: 94, cloudiness: 40, wind speed: 0.51
# 108: pacific grove lat: 36.6177, temp: 12, humidity: 67, cloudiness: 90, wind speed: 6.69
# 109: sirari lat: -1.2333, temp: 17, humidity: 89, cloudiness: 100, wind speed: 1.38
# 110: tsihombe lat: -1.2333, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 111: mar del plata lat: -38.0023, temp: 20, humidity: 88, cloudiness: 40, wind speed: 3.6
# 112: vao lat: -22.6667, temp: 23, humidity: 74, cloudiness: 22, wind speed: 2.71
# 113: busselton lat: -33.65, temp: 13, humidity: 83, cloudiness: 94, wind speed: 0.89
# 114: cape town lat: -33.9258, temp: 14, humidity: 94, cloudiness: 75, wind speed: 5.14
# 115: hihifo lat: -33.9258, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 116: bubaque lat: 11.2833, temp: 26, humidity: 67, cloudiness: 63, wind speed: 7.64
# 117: wembley lat: -31.9333, temp: 17, humidity: 52, cloudiness: 0, wind speed: 6.69
# 118: mahebourg lat: -20.4081, temp: 25, humidity: 94, cloudiness: 75, wind speed: 2.57
# 119: corinto lat: 37.9407, temp: 13, humidity: 55, cloudiness: 83, wind speed: 0.45
# 120: bima lat: -8.4667, temp: 22, humidity: 91, cloudiness: 33, wind speed: 1.3
# 121: olafsvik lat: 64.8945, temp: 6, humidity: 90, cloudiness: 100, wind speed: 9.36
# 122: bilma lat: 18.6853, temp: 32, humidity: 11, cloudiness: 0, wind speed: 2.77
# 123: lompoc lat: 34.6391, temp: 12, humidity: 71, cloudiness: 44, wind speed: 4.63
# 124: port-gentil lat: -0.7193, temp: 26, humidity: 84, cloudiness: 100, wind speed: 5.46
# 125: avarua lat: -21.2078, temp: 26, humidity: 83, cloudiness: 75, wind speed: 12.35
# 126: carnarvon lat: -24.8667, temp: 20, humidity: 60, cloudiness: 75, wind speed: 4.63
# 127: avera lat: 33.194, temp: 18, humidity: 19, cloudiness: 1, wind speed: 3.6
# 128: broken hill lat: -31.95, temp: 8, humidity: 81, cloudiness: 0, wind speed: 2.75
# 129: codrington lat: -38.2667, temp: 13, humidity: 75, cloudiness: 100, wind speed: 4.69
# 130: ushuaia lat: -54.8, temp: 7, humidity: 93, cloudiness: 75, wind speed: 5.14
# 131: alice springs lat: -23.7, temp: 8, humidity: 76, cloudiness: 0, wind speed: 2.06
# 132: upernavik lat: 72.7868, temp: -4, humidity: 87, cloudiness: 99, wind speed: 2.96
# 133: sao filipe lat: 14.8961, temp: 23, humidity: 72, cloudiness: 56, wind speed: 5.56
# 134: sur lat: 22.5667, temp: 30, humidity: 29, cloudiness: 7, wind speed: 7.43
# 135: ambilobe lat: -13.2, temp: 23, humidity: 88, cloudiness: 94, wind speed: 1.4
# 136: tumannyy lat: -13.2, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 137: lolua lat: -13.2, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 138: cabo san lucas lat: 22.8909, temp: 28, humidity: 44, cloudiness: 20, wind speed: 2.57
# 139: ximei lat: 24.9639, temp: 23, humidity: 88, cloudiness: 75, wind speed: 0.21
# 140: arlit lat: 18.7369, temp: 31, humidity: 6, cloudiness: 50, wind speed: 4.81
# 141: kruisfontein lat: -34.0033, temp: 19, humidity: 82, cloudiness: 5, wind speed: 1.79
# 142: cayenne lat: 4.9333, temp: 25, humidity: 94, cloudiness: 90, wind speed: 4.12
# 143: araouane lat: 18.9048, temp: 31, humidity: 11, cloudiness: 36, wind speed: 2.27
# 144: calvinia lat: -31.4707, temp: 19, humidity: 41, cloudiness: 0, wind speed: 1.54
# 145: bethel lat: 41.3712, temp: 6, humidity: 44, cloudiness: 94, wind speed: 1.79
# 146: sao joao da barra lat: -21.6403, temp: 23, humidity: 78, cloudiness: 40, wind speed: 6.17
# 147: skibbereen lat: 51.55, temp: 7, humidity: 87, cloudiness: 40, wind speed: 5.66
# 148: ketchikan lat: 55.3422, temp: 12, humidity: 30, cloudiness: 1, wind speed: 5.66
# 149: sabha lat: 27.0377, temp: 28, humidity: 17, cloudiness: 100, wind speed: 7.29
# 150: pevek lat: 69.7008, temp: -6, humidity: 71, cloudiness: 32, wind speed: 5
# 151: port lincoln lat: -34.7333, temp: 16, humidity: 71, cloudiness: 100, wind speed: 3.29
# 152: inirida lat: 3.8653, temp: 29, humidity: 74, cloudiness: 33, wind speed: 0.42
# 153: kavieng lat: -2.5744, temp: 28, humidity: 75, cloudiness: 90, wind speed: 3.39
# 154: lucapa lat: -8.4192, temp: 19, humidity: 95, cloudiness: 86, wind speed: 1.22
# 155: taoudenni lat: 22.6783, temp: 34, humidity: 8, cloudiness: 0, wind speed: 3.2
# 156: baglung lat: 28.2719, temp: 14, humidity: 35, cloudiness: 1, wind speed: 3.35
# 157: ye lat: 28.2719, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 158: cotorra lat: 9.0389, temp: 30, humidity: 64, cloudiness: 78, wind speed: 4.59
# 159: la ronge lat: 55.1001, temp: -3, humidity: 50, cloudiness: 98, wind speed: 7.2
# 160: cidreira lat: -30.1811, temp: 21, humidity: 73, cloudiness: 1, wind speed: 7.44
# 161: castro lat: -24.7911, temp: 15, humidity: 83, cloudiness: 100, wind speed: 1.81
# 162: port macquarie lat: -31.4333, temp: 13, humidity: 71, cloudiness: 0, wind speed: 0.45
# 163: buin lat: -33.7333, temp: 18, humidity: 49, cloudiness: 40, wind speed: 2.57
# 164: norman wells lat: 65.282, temp: -3, humidity: 50, cloudiness: 75, wind speed: 5.66
# 165: biharamulo lat: -2.6319, temp: 16, humidity: 96, cloudiness: 58, wind speed: 1.77
# 166: tecpan lat: 14.7623, temp: 23, humidity: 44, cloudiness: 40, wind speed: 5.14
# 167: vestmannaeyjar lat: 63.4427, temp: 7, humidity: 80, cloudiness: 100, wind speed: 11.33
# 168: kampil lat: 27.6167, temp: 25, humidity: 33, cloudiness: 0, wind speed: 3.3
# 169: barahona lat: 18.2085, temp: 29, humidity: 70, cloudiness: 75, wind speed: 6.17
# 170: colares lat: 38.7992, temp: 16, humidity: 74, cloudiness: 100, wind speed: 3.28
# 171: laarne lat: 51.0443, temp: 6, humidity: 78, cloudiness: 37, wind speed: 3.22
# 172: svetlogorsk lat: 52.6333, temp: 7, humidity: 93, cloudiness: 97, wind speed: 2.54
# 173: nanortalik lat: 60.1432, temp: 3, humidity: 75, cloudiness: 62, wind speed: 1.39
# 174: rocha lat: -34.4833, temp: 17, humidity: 84, cloudiness: 19, wind speed: 3.7
# 175: okmulgee lat: 35.6234, temp: 16, humidity: 36, cloudiness: 90, wind speed: 6.69
# 176: sumenep lat: -7.0167, temp: 25, humidity: 79, cloudiness: 53, wind speed: 1.96
# 177: saint-philippe lat: -21.3585, temp: 22, humidity: 78, cloudiness: 90, wind speed: 8.23
# 178: penzance lat: 50.1186, temp: 8, humidity: 66, cloudiness: 0, wind speed: 11.03
# 179: hofn lat: 64.2539, temp: 4, humidity: 79, cloudiness: 100, wind speed: 2.98
# 180: tombouctou lat: 20, temp: 31, humidity: 10, cloudiness: 17, wind speed: 2.24
# 181: council bluffs lat: 41.2619, temp: 13, humidity: 26, cloudiness: 75, wind speed: 7.72
# 182: kodiak lat: 57.79, temp: 6, humidity: 87, cloudiness: 90, wind speed: 5.66
# 183: lerwick lat: 60.1545, temp: 7, humidity: 70, cloudiness: 75, wind speed: 2.06
# 184: zhezkazgan lat: 47.8043, temp: 4, humidity: 40, cloudiness: 71, wind speed: 5.62
# 185: dingle lat: 10.9995, temp: 25, humidity: 85, cloudiness: 88, wind speed: 2.63
# 186: sao felix do xingu lat: -6.6447, temp: 23, humidity: 95, cloudiness: 92, wind speed: 0.39
# 187: ornskoldsvik lat: 63.2909, temp: 2, humidity: 51, cloudiness: 20, wind speed: 2.57
# 188: burnie lat: -41.0667, temp: 11, humidity: 68, cloudiness: 36, wind speed: 3.58
# 189: east london lat: -33.0153, temp: 20, humidity: 79, cloudiness: 97, wind speed: 5.5
# 190: te horo lat: -40.8084, temp: 16, humidity: 81, cloudiness: 100, wind speed: 2.68
# 191: hermanus lat: -34.4187, temp: 16, humidity: 85, cloudiness: 0, wind speed: 2.24
# 192: coahuayana lat: 18.7333, temp: 31, humidity: 25, cloudiness: 40, wind speed: 3.38
# 193: ploemeur lat: 47.7333, temp: 14, humidity: 62, cloudiness: 0, wind speed: 4.12
# 194: nago lat: 26.5881, temp: 21, humidity: 100, cloudiness: 75, wind speed: 10.29
# 195: provideniya lat: 64.3833, temp: 4, humidity: 52, cloudiness: 0, wind speed: 7
# 196: bentiu lat: 9.2333, temp: 29, humidity: 51, cloudiness: 93, wind speed: 3.12
# 197: nyagan lat: 62.1406, temp: 5, humidity: 82, cloudiness: 100, wind speed: 4.27
# 198: namibe lat: -15.1961, temp: 26, humidity: 81, cloudiness: 39, wind speed: 0.91
# 199: jacareacanga lat: -6.2222, temp: 24, humidity: 94, cloudiness: 78, wind speed: 0.36
# 200: salym lat: 60.0625, temp: -1, humidity: 74, cloudiness: 6, wind speed: 4.53
# 201: paamiut lat: 61.994, temp: 1, humidity: 83, cloudiness: 47, wind speed: 1.33
# 202: ca mau lat: 9.1769, temp: 26, humidity: 87, cloudiness: 100, wind speed: 2.2
# 203: tromso lat: 69.6496, temp: 0, humidity: 86, cloudiness: 75, wind speed: 1.54
# 204: tiksi lat: 71.6872, temp: -12, humidity: 90, cloudiness: 100, wind speed: 2.13
# 205: isangel lat: -19.55, temp: 27, humidity: 83, cloudiness: 75, wind speed: 3.83
# 206: bambous virieux lat: -20.3428, temp: 25, humidity: 94, cloudiness: 75, wind speed: 2.57
# 207: newport lat: 51.5877, temp: 9, humidity: 46, cloudiness: 0, wind speed: 4.63
# 208: chara lat: 56.9064, temp: -13, humidity: 74, cloudiness: 0, wind speed: 0.96
# 209: acarau lat: -2.8856, temp: 26, humidity: 81, cloudiness: 12, wind speed: 3.58
# 210: terney lat: 45.0503, temp: 9, humidity: 53, cloudiness: 100, wind speed: 1.42
# 211: los llanos de aridane lat: 28.6585, temp: 17, humidity: 73, cloudiness: 20, wind speed: 2.57
# 212: cotonou lat: 6.3654, temp: 29, humidity: 84, cloudiness: 20, wind speed: 5.14
# 213: thabazimbi lat: -24.5917, temp: 16, humidity: 46, cloudiness: 24, wind speed: 0.57
# 214: severo-kurilsk lat: 50.6789, temp: 2, humidity: 94, cloudiness: 68, wind speed: 1.8
# 215: gloversville lat: 43.0528, temp: 2, humidity: 55, cloudiness: 90, wind speed: 8.23
# 216: burica lat: 43.0528, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 217: constitucion lat: -35.3333, temp: 14, humidity: 81, cloudiness: 100, wind speed: 5.03
# 218: moratuwa lat: 6.773, temp: 29, humidity: 84, cloudiness: 40, wind speed: 3.6
# 219: strelka lat: 58.0728, temp: -7, humidity: 97, cloudiness: 26, wind speed: 0.4
# 220: lasa lat: 46.6166, temp: 9, humidity: 65, cloudiness: 0, wind speed: 1.03
# 221: oranjemund lat: -28.55, temp: 15, humidity: 87, cloudiness: 0, wind speed: 1.24
# 222: baculin lat: 7.4525, temp: 26, humidity: 79, cloudiness: 91, wind speed: 1.95
# 223: riyadh lat: 24.6877, temp: 30, humidity: 16, cloudiness: 0, wind speed: 2.57
# 224: parrsboro lat: 45.4001, temp: 2, humidity: 70, cloudiness: 95, wind speed: 6.17
# 225: lima lat: -12.0432, temp: 19, humidity: 82, cloudiness: 75, wind speed: 5.14
# 226: anadyr lat: 64.75, temp: -12, humidity: 85, cloudiness: 20, wind speed: 6
# 227: menongue lat: -14.6585, temp: 20, humidity: 59, cloudiness: 84, wind speed: 2.29
# 228: nan lat: 18.8333, temp: 25, humidity: 63, cloudiness: 19, wind speed: 0.24
# 229: luderitz lat: -26.6481, temp: 18, humidity: 72, cloudiness: 1, wind speed: 2.86
# 230: estelle lat: 29.8458, temp: 19, humidity: 48, cloudiness: 40, wind speed: 5.66
# 231: road town lat: 18.4167, temp: 27, humidity: 65, cloudiness: 20, wind speed: 4.12
# 232: vanavara lat: 60.34, temp: -4, humidity: 89, cloudiness: 95, wind speed: 3.47
# 233: hobart lat: -42.8794, temp: 11, humidity: 58, cloudiness: 75, wind speed: 3.09
# 234: ust-kulom lat: 61.6864, temp: 5, humidity: 85, cloudiness: 100, wind speed: 4.1
# 235: ust-uda lat: 54.1742, temp: -5, humidity: 81, cloudiness: 41, wind speed: 1.24
# 236: attawapiskat lat: 54.1742, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 237: naze lat: 28.3667, temp: 21, humidity: 83, cloudiness: 75, wind speed: 7.72
# 238: tabarqah lat: 28.3667, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 239: atar lat: 20.5169, temp: 28, humidity: 11, cloudiness: 0, wind speed: 2.69
# 240: baldone lat: 56.7428, temp: 4, humidity: 75, cloudiness: 90, wind speed: 5.66
# 241: guerrero negro lat: 27.9769, temp: 18, humidity: 54, cloudiness: 2, wind speed: 8.55
# 242: along lat: 28.1667, temp: 18, humidity: 96, cloudiness: 62, wind speed: 0.6
# 243: hay river lat: 60.8156, temp: -4, humidity: 54, cloudiness: 100, wind speed: 6.17
# 244: vila velha lat: -20.3297, temp: 25, humidity: 78, cloudiness: 75, wind speed: 3.6
# 245: luganville lat: -15.5333, temp: 29, humidity: 75, cloudiness: 46, wind speed: 4.1
# 246: arraial do cabo lat: -22.9661, temp: 22, humidity: 88, cloudiness: 20, wind speed: 7.72
# 247: karla lat: 59.3723, temp: 3, humidity: 81, cloudiness: 0, wind speed: 2.06
# 248: deniliquin lat: -35.5333, temp: 9, humidity: 89, cloudiness: 80, wind speed: 2.76
# 249: kayanga lat: -1.5303, temp: 13, humidity: 96, cloudiness: 57, wind speed: 1.14
# 250: nguiu lat: -1.5303, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 251: mersing lat: 2.4312, temp: 24, humidity: 94, cloudiness: 100, wind speed: 1.54
# 252: yatou lat: 37.15, temp: 12, humidity: 81, cloudiness: 100, wind speed: 8.59
# 253: kamenskoye lat: 37.15, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 254: palmer lat: 42.1584, temp: 6, humidity: 27, cloudiness: 40, wind speed: 11.83
# 255: najran lat: 17.4924, temp: 22, humidity: 20, cloudiness: 0, wind speed: 2.06
# 256: le pont-de-claix lat: 45.1244, temp: 8, humidity: 76, cloudiness: 0, wind speed: 2.06
# 257: shache lat: 38.4167, temp: 11, humidity: 15, cloudiness: 15, wind speed: 3.82
# 258: stange lat: 60.718, temp: 2, humidity: 59, cloudiness: 25, wind speed: 1.79
# 259: bathsheba lat: 13.2167, temp: 28, humidity: 57, cloudiness: 20, wind speed: 9.26
# 260: tawkar lat: 13.2167, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 261: tadine lat: -21.55, temp: 26, humidity: 76, cloudiness: 25, wind speed: 3.67
# 262: port hedland lat: -20.3167, temp: 18, humidity: 36, cloudiness: 0, wind speed: 4.12
# 263: marawi lat: 7.9986, temp: 24, humidity: 85, cloudiness: 72, wind speed: 1.79
# 264: parkes lat: -33.1333, temp: 8, humidity: 78, cloudiness: 0, wind speed: 0.78
# 265: saleaula lat: -33.1333, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 266: igarka lat: 67.4667, temp: 0, humidity: 95, cloudiness: 100, wind speed: 5.61
# 267: vila franca do campo lat: 37.7167, temp: 15, humidity: 77, cloudiness: 40, wind speed: 14.4
# 268: mayumba lat: -3.432, temp: 25, humidity: 88, cloudiness: 100, wind speed: 3.76
# 269: evensk lat: 61.95, temp: -3, humidity: 91, cloudiness: 94, wind speed: 1.68
# 270: sola lat: -13.8833, temp: 27, humidity: 94, cloudiness: 90, wind speed: 1.54
# 271: filadelfia lat: 39.9523, temp: 9, humidity: 29, cloudiness: 75, wind speed: 10.8
# 272: salalah lat: 17.0151, temp: 27, humidity: 69, cloudiness: 0, wind speed: 1.54
# 273: airai lat: -8.9266, temp: 14, humidity: 85, cloudiness: 34, wind speed: 0.95
# 274: madras lat: 13.0878, temp: 28, humidity: 83, cloudiness: 40, wind speed: 2.06
# 275: bud lat: 39.447, temp: 12, humidity: 40, cloudiness: 68, wind speed: 5.11
# 276: new norfolk lat: -42.7826, temp: 9, humidity: 63, cloudiness: 70, wind speed: 0.45
# 277: urusha lat: 54.05, temp: -4, humidity: 57, cloudiness: 99, wind speed: 2.08
# 278: palabuhanratu lat: 54.05, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 279: jiaohe lat: 43.7286, temp: 13, humidity: 78, cloudiness: 100, wind speed: 1.11
# 280: terrace bay lat: 48.7834, temp: 5, humidity: 70, cloudiness: 40, wind speed: 3.6
# 281: dir lat: 35.2058, temp: 8, humidity: 47, cloudiness: 15, wind speed: 4.62
# 282: kariba lat: -16.5167, temp: 19, humidity: 73, cloudiness: 3, wind speed: 1.8
# 283: salta lat: -24.7859, temp: 20, humidity: 68, cloudiness: 40, wind speed: 2.57
# 284: faanui lat: -16.4833, temp: 27, humidity: 74, cloudiness: 12, wind speed: 6.85
# 285: vigrestad lat: 58.5667, temp: 3, humidity: 82, cloudiness: 7, wind speed: 8.22
# 286: the valley lat: 18.217, temp: 27, humidity: 74, cloudiness: 20, wind speed: 6.69
# 287: derzhavinsk lat: 51.1, temp: 4, humidity: 50, cloudiness: 98, wind speed: 5
# 288: la rioja lat: 42.25, temp: 12, humidity: 82, cloudiness: 90, wind speed: 2.06
# 289: watertown lat: 42.3709, temp: 7, humidity: 39, cloudiness: 90, wind speed: 7.72
# 290: yellowknife lat: 62.456, temp: -8, humidity: 49, cloudiness: 75, wind speed: 9.77
# 291: gornopravdinsk lat: 60.05, temp: 0, humidity: 74, cloudiness: 29, wind speed: 4.7
# 292: emerald lat: -23.5333, temp: 17, humidity: 72, cloudiness: 90, wind speed: 5.14
# 293: nizhniy baskunchak lat: 48.2198, temp: 11, humidity: 68, cloudiness: 88, wind speed: 1.94
# 294: melo lat: -32.3667, temp: 19, humidity: 69, cloudiness: 90, wind speed: 5.15
# 295: culpeper lat: 38.5004, temp: 11, humidity: 24, cloudiness: 75, wind speed: 5.14
# 296: sao jose da coroa grande lat: -8.8978, temp: 26, humidity: 82, cloudiness: 13, wind speed: 3.83
# 297: katobu lat: -4.9408, temp: 23, humidity: 93, cloudiness: 29, wind speed: 0.49
# 298: saint george lat: 37.1041, temp: 24, humidity: 16, cloudiness: 1, wind speed: 4.63
# 299: daokou lat: 35.5639, temp: 10, humidity: 90, cloudiness: 75, wind speed: 3.71
# 300: lugovskiy lat: 35.5639, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 301: sorland lat: 67.667, temp: -1, humidity: 93, cloudiness: 75, wind speed: 1.54
# 302: liku lat: -0.7275, temp: 24, humidity: 90, cloudiness: 84, wind speed: 0.97
# 303: sanchor lat: 24.7553, temp: 26, humidity: 63, cloudiness: 0, wind speed: 4.02
# 304: poum lat: -20.2333, temp: 26, humidity: 79, cloudiness: 66, wind speed: 5.78
# 305: lagoa lat: 39.05, temp: 14, humidity: 78, cloudiness: 47, wind speed: 18.81
# 306: novoagansk lat: 61.9449, temp: -3, humidity: 88, cloudiness: 16, wind speed: 4.09
# 307: sayyan lat: 15.1718, temp: 15, humidity: 27, cloudiness: 13, wind speed: 1.16
# 308: hobyo lat: 5.3505, temp: 29, humidity: 72, cloudiness: 76, wind speed: 5.4
# 309: bafia lat: 4.75, temp: 22, humidity: 94, cloudiness: 36, wind speed: 1.06
# 310: tiznit lat: 29.5833, temp: 15, humidity: 73, cloudiness: 8, wind speed: 2.08
# 311: khash lat: 28.2211, temp: 19, humidity: 29, cloudiness: 0, wind speed: 1.66
# 312: kyabe lat: 9.4515, temp: 32, humidity: 31, cloudiness: 61, wind speed: 0.27
# 313: aktash lat: 50.3, temp: -15, humidity: 94, cloudiness: 99, wind speed: 0.53
# 314: karcsa lat: 48.3113, temp: 5, humidity: 87, cloudiness: 0, wind speed: 2.06
# 315: price lat: 39.5994, temp: 16, humidity: 12, cloudiness: 1, wind speed: 4.12
# 316: ulladulla lat: -35.35, temp: 12, humidity: 62, cloudiness: 0, wind speed: 5.66
# 317: boundiali lat: 9.5217, temp: 27, humidity: 58, cloudiness: 93, wind speed: 0.74
# 318: clyde river lat: 70.4692, temp: -9, humidity: 79, cloudiness: 75, wind speed: 2.57
# 319: sao borja lat: -28.6606, temp: 22, humidity: 63, cloudiness: 63, wind speed: 2.63
# 320: andevoranto lat: -28.6606, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 321: westport lat: 41.1415, temp: 7, humidity: 41, cloudiness: 97, wind speed: 0.45
# 322: ewa beach lat: 21.3156, temp: 28, humidity: 57, cloudiness: 75, wind speed: 6.17
# 323: biak lat: -0.9131, temp: 25, humidity: 83, cloudiness: 100, wind speed: 2.07
# 324: ozieri lat: 40.586, temp: 11, humidity: 100, cloudiness: 75, wind speed: 0.51
# 325: uribia lat: 11.7139, temp: 32, humidity: 43, cloudiness: 7, wind speed: 6.7
# 326: jaumave lat: 23.4167, temp: 30, humidity: 42, cloudiness: 40, wind speed: 8.23
# 327: acapulco lat: 16.8634, temp: 30, humidity: 58, cloudiness: 40, wind speed: 5.66
# 328: bluff lat: -46.6, temp: 9, humidity: 98, cloudiness: 100, wind speed: 3.13
# 329: ballina lat: -28.8667, temp: 12, humidity: 62, cloudiness: 0, wind speed: 3.09
# 330: broome lat: 42.2506, temp: 2, humidity: 55, cloudiness: 90, wind speed: 7.72
# 331: torbay lat: 47.6666, temp: 5, humidity: 87, cloudiness: 90, wind speed: 9.77
# 332: edmundston lat: 47.3737, temp: -2, humidity: 93, cloudiness: 100, wind speed: 5.14
# 333: khandyga lat: 62.6667, temp: -11, humidity: 91, cloudiness: 99, wind speed: 1.35
# 334: kaeo lat: -35.1, temp: 19, humidity: 76, cloudiness: 99, wind speed: 2.73
# 335: lukulu lat: -14.3707, temp: 21, humidity: 52, cloudiness: 59, wind speed: 2.73
# 336: alekseyevsk lat: 57.8406, temp: -8, humidity: 95, cloudiness: 35, wind speed: 2.05
# 337: jinchang lat: 38.4953, temp: 13, humidity: 67, cloudiness: 50, wind speed: 1.33
# 338: peniche lat: 39.3558, temp: 14, humidity: 85, cloudiness: 100, wind speed: 3.47
# 339: port alfred lat: -33.5906, temp: 20, humidity: 80, cloudiness: 65, wind speed: 8.38
# 340: umzimvubu lat: -33.5906, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 341: pilar lat: -9.5972, temp: 25, humidity: 94, cloudiness: 0, wind speed: 2.57
# 342: lakes entrance lat: -37.8811, temp: 13, humidity: 74, cloudiness: 81, wind speed: 5.07
# 343: kingaroy lat: -26.5333, temp: 9, humidity: 87, cloudiness: 15, wind speed: 2.06
# 344: batticaloa lat: 7.7102, temp: 27, humidity: 76, cloudiness: 29, wind speed: 0.73
# 345: pousat lat: 7.7102, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 346: johnstown lat: 40.3267, temp: 4, humidity: 38, cloudiness: 90, wind speed: 6.69
# 347: karratha lat: -20.7377, temp: 24, humidity: 28, cloudiness: 0, wind speed: 5.63
# 348: dzilam gonzalez lat: 21.2833, temp: 30, humidity: 58, cloudiness: 67, wind speed: 4.27
# 349: mildura lat: -34.2, temp: 13, humidity: 71, cloudiness: 90, wind speed: 4.33
# 350: tsimlyansk lat: 47.6461, temp: 10, humidity: 92, cloudiness: 100, wind speed: 1.72
# 351: pangkalanbuun lat: -2.6833, temp: 23, humidity: 91, cloudiness: 72, wind speed: 0.52
# 352: kysyl-syr lat: 63.8986, temp: -3, humidity: 94, cloudiness: 100, wind speed: 4.49
# 353: colac lat: -38.3333, temp: 9, humidity: 98, cloudiness: 100, wind speed: 3.11
# 354: mulege lat: 26.8833, temp: 27, humidity: 26, cloudiness: 94, wind speed: 2.99
# 355: dakar lat: 14.6937, temp: 20, humidity: 94, cloudiness: 0, wind speed: 3.09
# 356: termini imerese lat: 37.9837, temp: 15, humidity: 87, cloudiness: 100, wind speed: 3.13
# 357: opuwo lat: -18.0607, temp: 23, humidity: 31, cloudiness: 99, wind speed: 1.24
# 358: sentyabrskiy lat: -18.0607, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 359: margate lat: 51.3813, temp: 5, humidity: 73, cloudiness: 8, wind speed: 0.89
# 360: eskil lat: 38.4017, temp: 11, humidity: 37, cloudiness: 0, wind speed: 1.98
# 361: storm lake lat: 42.6411, temp: 14, humidity: 21, cloudiness: 1, wind speed: 6.17
# 362: nantucket lat: 41.2835, temp: 7, humidity: 46, cloudiness: 40, wind speed: 11.32
# 363: tynda lat: 55.1667, temp: -8, humidity: 80, cloudiness: 97, wind speed: 1.51
# 364: tazovskiy lat: 67.4667, temp: -1, humidity: 90, cloudiness: 98, wind speed: 7.56
# 365: henties bay lat: -22.116, temp: 18, humidity: 84, cloudiness: 84, wind speed: 0.89
# 366: matara lat: 5.9485, temp: 25, humidity: 89, cloudiness: 31, wind speed: 3.51
# 367: pondicherry lat: 11.93, temp: 27, humidity: 80, cloudiness: 17, wind speed: 4.08
# 368: zatyshshya lat: 47.3335, temp: 10, humidity: 73, cloudiness: 64, wind speed: 4.86
# 369: axim lat: 4.8699, temp: 28, humidity: 83, cloudiness: 100, wind speed: 4.47
# 370: noumea lat: -22.2763, temp: 26, humidity: 78, cloudiness: 0, wind speed: 2.57
# 371: french harbor lat: 16.35, temp: 29, humidity: 66, cloudiness: 20, wind speed: 9.26
# 372: tshikapa lat: -6.4167, temp: 22, humidity: 94, cloudiness: 99, wind speed: 1.11
# 373: porteirinha lat: -15.7433, temp: 23, humidity: 59, cloudiness: 42, wind speed: 1.63
# 374: richards bay lat: -28.783, temp: 20, humidity: 89, cloudiness: 88, wind speed: 1.64
# 375: pangnirtung lat: 66.1451, temp: -6, humidity: 86, cloudiness: 75, wind speed: 4.12
# 376: souillac lat: -20.5167, temp: 25, humidity: 94, cloudiness: 75, wind speed: 2.57
# 377: vytegra lat: 61.0064, temp: 3, humidity: 91, cloudiness: 53, wind speed: 3.6
# 378: baturaja lat: -4.1333, temp: 22, humidity: 97, cloudiness: 100, wind speed: 0.5
# 379: moose factory lat: 51.2585, temp: 3, humidity: 60, cloudiness: 90, wind speed: 4.12
# 380: ubinskoye lat: 55.3068, temp: -1, humidity: 85, cloudiness: 11, wind speed: 2.54
# 381: wawa lat: 9.9022, temp: 30, humidity: 55, cloudiness: 67, wind speed: 2.07
# 382: abha lat: 18.2164, temp: 17, humidity: 48, cloudiness: 0, wind speed: 1.54
# 383: san juan lat: -31.5375, temp: 20, humidity: 40, cloudiness: 4, wind speed: 4.55
# 384: lac du bonnet lat: 50.2536, temp: 19, humidity: 21, cloudiness: 20, wind speed: 4.92
# 385: abu dhabi lat: 24.4667, temp: 27, humidity: 57, cloudiness: 0, wind speed: 2.06
# 386: ovejas lat: 9.5325, temp: 29, humidity: 68, cloudiness: 75, wind speed: 4.96
# 387: falam lat: 22.9167, temp: 16, humidity: 64, cloudiness: 1, wind speed: 1.65
# 388: mpwapwa lat: -6.35, temp: 17, humidity: 97, cloudiness: 47, wind speed: 1.81
# 389: chokurdakh lat: 70.6333, temp: -18, humidity: 97, cloudiness: 98, wind speed: 2.74
# 390: carutapera lat: -1.195, temp: 24, humidity: 91, cloudiness: 100, wind speed: 1.73
# 391: port blair lat: 11.6667, temp: 27, humidity: 76, cloudiness: 63, wind speed: 2.52
# 392: marzuq lat: 14.4, temp: 21, humidity: 46, cloudiness: 1, wind speed: 2.38
# 393: rosarito lat: 32.3333, temp: 15, humidity: 77, cloudiness: 90, wind speed: 3.6
# 394: campbellford lat: 44.3084, temp: 5, humidity: 38, cloudiness: 75, wind speed: 10.29
# 395: makakilo city lat: 21.3469, temp: 28, humidity: 57, cloudiness: 75, wind speed: 6.17
# 396: byron bay lat: -28.65, temp: 12, humidity: 62, cloudiness: 0, wind speed: 3.09
# 397: skawina lat: 49.9752, temp: 4, humidity: 60, cloudiness: 40, wind speed: 3.09
# 398: barcelos lat: 41.5388, temp: 14, humidity: 88, cloudiness: 0, wind speed: 1.03
# 399: tecoanapa lat: 16.5167, temp: 31, humidity: 49, cloudiness: 40, wind speed: 5.02
# 400: george lat: -33.963, temp: 14, humidity: 100, cloudiness: 40, wind speed: 1.54
# 401: slave lake lat: 55.2834, temp: 0, humidity: 43, cloudiness: 1, wind speed: 4.12
# 402: juneau lat: 58.3019, temp: 9, humidity: 30, cloudiness: 20, wind speed: 4.63
# 403: xiongshi lat: 58.3019, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 404: jackson lat: 42.4165, temp: 23, humidity: 24, cloudiness: 1, wind speed: 5.03
# 405: locri lat: 38.2414, temp: 17, humidity: 59, cloudiness: 75, wind speed: 3.6
# 406: pingzhuang lat: 42.0372, temp: 8, humidity: 91, cloudiness: 100, wind speed: 2.44
# 407: bom jesus lat: -9.0744, temp: 24, humidity: 83, cloudiness: 32, wind speed: 0.64
# 408: yei lat: 4.095, temp: 20, humidity: 80, cloudiness: 96, wind speed: 1.7
# 409: verkhnevilyuysk lat: 63.4453, temp: -3, humidity: 94, cloudiness: 100, wind speed: 5.03
# 410: russell lat: 32.3502, temp: 19, humidity: 19, cloudiness: 1, wind speed: 2.16
# 411: gat lat: 31.61, temp: 16, humidity: 77, cloudiness: 40, wind speed: 1.54
# 412: san cristobal lat: 7.7669, temp: 32, humidity: 51, cloudiness: 20, wind speed: 4.63
# 413: mahibadhoo lat: 3.7833, temp: 28, humidity: 76, cloudiness: 96, wind speed: 5.55
# 414: san policarpo lat: 12.1791, temp: 25, humidity: 88, cloudiness: 95, wind speed: 2.29
# 415: ancud lat: -41.8697, temp: 10, humidity: 100, cloudiness: 75, wind speed: 3.6
# 416: morgan city lat: 29.6994, temp: 21, humidity: 53, cloudiness: 1, wind speed: 4.63
# 417: tayu lat: -6.5397, temp: 24, humidity: 83, cloudiness: 18, wind speed: 2.57
# 418: flinders lat: -34.5833, temp: 14, humidity: 60, cloudiness: 0, wind speed: 0.89
# 419: grand river south east lat: -34.5833, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 420: bantry lat: 51.6833, temp: 7, humidity: 87, cloudiness: 40, wind speed: 5.66
# 421: rolim de moura lat: 51.6833, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 422: khatanga lat: 71.9667, temp: -3, humidity: 97, cloudiness: 99, wind speed: 2.93
# 423: salinopolis lat: -0.6136, temp: 25, humidity: 87, cloudiness: 100, wind speed: 3.01
# 424: taseyevo lat: 57.2169, temp: -7, humidity: 96, cloudiness: 7, wind speed: 0.71
# 425: oistins lat: 13.0667, temp: 28, humidity: 57, cloudiness: 20, wind speed: 9.26
# 426: tarashcha lat: 49.5583, temp: 9, humidity: 85, cloudiness: 26, wind speed: 5.04
# 427: pitimbu lat: -7.4706, temp: 27, humidity: 89, cloudiness: 20, wind speed: 3.6
# 428: basco lat: 20.4487, temp: 26, humidity: 79, cloudiness: 31, wind speed: 6.99
# 429: diapaga lat: 12.0708, temp: 34, humidity: 25, cloudiness: 60, wind speed: 1.72
# 430: banmo lat: 12.0708, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 431: vaitupu lat: 12.0708, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 432: borogontsy lat: 62.6683, temp: -10, humidity: 89, cloudiness: 32, wind speed: 2.47
# 433: rio tercero lat: -32.173, temp: 16, humidity: 90, cloudiness: 98, wind speed: 2.24
# 434: adrar lat: 20.5022, temp: 27, humidity: 11, cloudiness: 0, wind speed: 5.26
# 435: obo lat: 5.3998, temp: 21, humidity: 90, cloudiness: 99, wind speed: 1.35
# 436: santiago del estero lat: -27.7951, temp: 19, humidity: 93, cloudiness: 100, wind speed: 2.62
# 437: garden city lat: 42.3256, temp: 10, humidity: 37, cloudiness: 75, wind speed: 7.2
# 438: nisporeni lat: 47.0814, temp: 12, humidity: 66, cloudiness: 0, wind speed: 0.51
# 439: kattivakkam lat: 13.2167, temp: 28, humidity: 83, cloudiness: 40, wind speed: 2.06
# 440: robertsport lat: 6.7533, temp: 28, humidity: 82, cloudiness: 100, wind speed: 3.96
# 441: port hardy lat: 50.6996, temp: 11, humidity: 71, cloudiness: 20, wind speed: 2.57
# 442: kandiari lat: 26.9156, temp: 30, humidity: 25, cloudiness: 0, wind speed: 3.77
# 443: north bend lat: 43.4065, temp: 15, humidity: 67, cloudiness: 1, wind speed: 5.14
# 444: los alamos lat: 35.8881, temp: 16, humidity: 12, cloudiness: 1, wind speed: 7.2
# 445: yefira lat: 35.8881, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 446: buenos aires lat: -34.6132, temp: 22, humidity: 83, cloudiness: 0, wind speed: 4.12
# 447: lumeje lat: -11.55, temp: 20, humidity: 69, cloudiness: 73, wind speed: 1.28
# 448: tura lat: 25.5198, temp: 21, humidity: 66, cloudiness: 57, wind speed: 0.63
# 449: lavagna lat: 44.3079, temp: 11, humidity: 84, cloudiness: 1, wind speed: 2.47
# 450: mago lat: 53.2514, temp: 5, humidity: 87, cloudiness: 100, wind speed: 1.06
# 451: mareeba lat: -17, temp: 23, humidity: 94, cloudiness: 40, wind speed: 4.12
# 452: aylmer lat: 42.7668, temp: 5, humidity: 56, cloudiness: 75, wind speed: 7.2
# 453: killybegs lat: 54.6333, temp: 11, humidity: 54, cloudiness: 0, wind speed: 4.12
# 454: popondetta lat: -8.7537, temp: 26, humidity: 85, cloudiness: 100, wind speed: 0.62
# 455: mill valley lat: 37.906, temp: 12, humidity: 87, cloudiness: 42, wind speed: 0.89
# 456: scarborough lat: 54.2797, temp: 5, humidity: 76, cloudiness: 79, wind speed: 2.55
# 457: sergeyevka lat: 53.88, temp: 4, humidity: 52, cloudiness: 95, wind speed: 5.29
# 458: tateyama lat: 34.9833, temp: 13, humidity: 57, cloudiness: 7, wind speed: 0.89
# 459: koster lat: -25.863, temp: 14, humidity: 45, cloudiness: 31, wind speed: 2.43
# 460: allapalli lat: 19.4167, temp: 29, humidity: 39, cloudiness: 82, wind speed: 1.29
# 461: at-bashi lat: 41.1702, temp: -2, humidity: 68, cloudiness: 11, wind speed: 0.51
# 462: marion lat: 39.7684, temp: 11, humidity: 35, cloudiness: 75, wind speed: 8.23
# 463: elko lat: 41.0002, temp: 16, humidity: 12, cloudiness: 1, wind speed: 5.14
# 464: tuktoyaktuk lat: 69.4541, temp: -12, humidity: 72, cloudiness: 40, wind speed: 4.12
# 465: gabu lat: 12.2833, temp: 29, humidity: 43, cloudiness: 7, wind speed: 4.16
# 466: kahului lat: 20.8947, temp: 26, humidity: 48, cloudiness: 40, wind speed: 8.75
# 467: san carlos de bariloche lat: -41.1456, temp: 13, humidity: 35, cloudiness: 75, wind speed: 7.2
# 468: pangoa lat: -12.1167, temp: 23, humidity: 94, cloudiness: 50, wind speed: 0.97
# 469: mount isa lat: -20.7333, temp: 19, humidity: 32, cloudiness: 29, wind speed: 3.6
# 470: nizhneyansk lat: -20.7333, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 471: kalabo lat: -14.97, temp: 19, humidity: 52, cloudiness: 16, wind speed: 2.82
# 472: les cayes lat: 18.2, temp: 27, humidity: 70, cloudiness: 15, wind speed: 4.25
# 473: samalaeulu lat: 18.2, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 474: vostok lat: 46.4856, temp: 10, humidity: 45, cloudiness: 100, wind speed: 1.6
# 475: antalaha lat: -14.9003, temp: 23, humidity: 90, cloudiness: 88, wind speed: 3.27
# 476: maldonado lat: -34.6667, temp: 22, humidity: 64, cloudiness: 20, wind speed: 3.6
# 477: banda aceh lat: 5.5577, temp: 27, humidity: 80, cloudiness: 93, wind speed: 4.51
# 478: neiafu lat: -18.65, temp: 29, humidity: 79, cloudiness: 40, wind speed: 4.12
# 479: beira lat: -19.8436, temp: 24, humidity: 69, cloudiness: 20, wind speed: 2.58
# 480: aketi lat: 2.7388, temp: 24, humidity: 79, cloudiness: 63, wind speed: 0.44
# 481: ust-kamchatsk lat: 2.7388, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 482: cap-aux-meules lat: 47.3821, temp: 4, humidity: 93, cloudiness: 99, wind speed: 6.69
# 483: tessalit lat: 20.1986, temp: 30, humidity: 7, cloudiness: 0, wind speed: 3.4
# 484: nuevo progreso lat: 23.1667, temp: 29, humidity: 68, cloudiness: 90, wind speed: 3.13
# 485: durazno lat: -33.4131, temp: 23, humidity: 68, cloudiness: 75, wind speed: 3.6
# 486: nishihara lat: 26.1842, temp: 21, humidity: 94, cloudiness: 90, wind speed: 10.29
# 487: maheshwar lat: 22.1833, temp: 23, humidity: 23, cloudiness: 66, wind speed: 2.43
# 488: fairbanks lat: 64.8378, temp: 11, humidity: 31, cloudiness: 1, wind speed: 5.66
# 489: dudinka lat: 69.4058, temp: 1, humidity: 95, cloudiness: 100, wind speed: 7.67
# 490: bayan lat: 46.0833, temp: 12, humidity: 87, cloudiness: 100, wind speed: 0.94
# 491: rio grande lat: -32.035, temp: 22, humidity: 73, cloudiness: 0, wind speed: 10.29
# 492: meulaboh lat: 4.1363, temp: 25, humidity: 88, cloudiness: 88, wind speed: 1.36
# 493: shubarshi lat: 48.5872, temp: 10, humidity: 46, cloudiness: 100, wind speed: 8.26
# 494: stornoway lat: 58.2093, temp: 5, humidity: 93, cloudiness: 100, wind speed: 1.54
# 495: leh lat: 34.1667, temp: -3, humidity: 72, cloudiness: 93, wind speed: 2.67
# 496: hendek lat: 40.7994, temp: 8, humidity: 93, cloudiness: 0, wind speed: 2.06
# 497: igrim lat: 63.1906, temp: 5, humidity: 83, cloudiness: 97, wind speed: 3.88
# 498: det udom lat: 14.906, temp: 26, humidity: 94, cloudiness: 0, wind speed: 1.03
# 499: san patricio lat: 28.017, temp: 22, humidity: 78, cloudiness: 90, wind speed: 7.72
# 500: puerto morazan lat: 12.8504, temp: 35, humidity: 31, cloudiness: 40, wind speed: 2.06
# 501: salinas lat: 36.6777, temp: 13, humidity: 67, cloudiness: 90, wind speed: 5.66
# 502: natal lat: -5.795, temp: 27, humidity: 78, cloudiness: 40, wind speed: 3.09
# 503: korla lat: 41.7597, temp: 6, humidity: 54, cloudiness: 100, wind speed: 7.71
# 504: grand-lahou lat: 5.1367, temp: 28, humidity: 86, cloudiness: 63, wind speed: 5.2
# 505: kargasok lat: 59.0556, temp: -6, humidity: 91, cloudiness: 19, wind speed: 2.03
# 506: tirumullaivasal lat: 11.2333, temp: 27, humidity: 80, cloudiness: 39, wind speed: 3.21
# 507: ternate lat: 0.8, temp: 27, humidity: 77, cloudiness: 88, wind speed: 0.88
# 508: talara lat: -4.5772, temp: 28, humidity: 57, cloudiness: 0, wind speed: 8.75
# 509: panguipulli lat: -39.6333, temp: 14, humidity: 54, cloudiness: 0, wind speed: 2.06
# 510: kirakira lat: -10.4544, temp: 29, humidity: 76, cloudiness: 100, wind speed: 2.58
# 511: tautira lat: -17.7333, temp: 29, humidity: 65, cloudiness: 20, wind speed: 3.6
# 512: olinda lat: -8.0089, temp: 27, humidity: 69, cloudiness: 20, wind speed: 2.57
# 513: saint-joseph lat: -21.3667, temp: 22, humidity: 78, cloudiness: 90, wind speed: 8.23
# 514: zhanatas lat: -21.3667, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 515: nioro lat: 13.35, temp: 27, humidity: 41, cloudiness: 14, wind speed: 4.69
# 516: hervey bay lat: -25.2986, temp: 17, humidity: 72, cloudiness: 92, wind speed: 0.45
# 517: camacha lat: 33.0833, temp: 20, humidity: 83, cloudiness: 20, wind speed: 0.51
# 518: fort nelson lat: 58.8053, temp: 4, humidity: 28, cloudiness: 75, wind speed: 4.12
# 519: rathdrum lat: 47.8137, temp: 13, humidity: 54, cloudiness: 90, wind speed: 10.29
# 520: auki lat: -8.7676, temp: 28, humidity: 71, cloudiness: 81, wind speed: 1.24
# 521: marcona lat: -8.7676, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 522: saldanha lat: -33.0117, temp: 16, humidity: 82, cloudiness: 0, wind speed: 1.54
# 523: bratsk lat: 56.1325, temp: -6, humidity: 49, cloudiness: 9, wind speed: 0.95
# 524: nanakuli lat: 21.3906, temp: 27, humidity: 57, cloudiness: 75, wind speed: 6.17
# 525: honiara lat: -9.4333, temp: 29, humidity: 72, cloudiness: 82, wind speed: 2.12
# 526: hamina lat: 60.5697, temp: 4, humidity: 75, cloudiness: 0, wind speed: 1.54
# 527: parrita lat: 9.5201, temp: 25, humidity: 60, cloudiness: 40, wind speed: 8.23
# 528: hopkinsville lat: 36.8656, temp: 15, humidity: 35, cloudiness: 1, wind speed: 2.6
# 529: tarudant lat: 36.8656, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 530: teresopolis lat: -22.4122, temp: 17, humidity: 86, cloudiness: 46, wind speed: 0.8
# 531: pocao de pedras lat: -4.6667, temp: 25, humidity: 93, cloudiness: 95, wind speed: 1.4
# 532: lokosovo lat: 61.1333, temp: -2, humidity: 83, cloudiness: 17, wind speed: 4.4
# 533: kokopo lat: -4.352, temp: 26, humidity: 80, cloudiness: 79, wind speed: 0.99
# 534: rawannawi lat: -4.352, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 535: kuvshinovo lat: 57.0295, temp: 6, humidity: 90, cloudiness: 61, wind speed: 3.48
# 536: felipe carrillo puerto lat: 19.5833, temp: 32, humidity: 35, cloudiness: 2, wind speed: 3.93
# 537: discovery bay lat: 37.9085, temp: 24, humidity: 38, cloudiness: 1, wind speed: 10.29
# 538: ogulin lat: 45.2661, temp: 11, humidity: 87, cloudiness: 0, wind speed: 0.51
# 539: cockburn town lat: 21.4612, temp: 26, humidity: 78, cloudiness: 0, wind speed: 6.84
# 540: sept-iles lat: 50.2001, temp: 5, humidity: 100, cloudiness: 90, wind speed: 1.54
# 541: gulu lat: 2.7746, temp: 19, humidity: 94, cloudiness: 100, wind speed: 2.24
# 542: starogard gdanski lat: 53.964, temp: 3, humidity: 100, cloudiness: 96, wind speed: 5.81
# 543: junction city lat: 39.0286, temp: 13, humidity: 33, cloudiness: 90, wind speed: 7.72
# 544: caninde lat: -4.3589, temp: 24, humidity: 94, cloudiness: 76, wind speed: 1.16
# 545: ust-maya lat: 60.4167, temp: -6, humidity: 80, cloudiness: 100, wind speed: 3.72
# 546: enshi lat: 30.3, temp: 19, humidity: 93, cloudiness: 96, wind speed: 1.28
# 547: pokhara lat: 28.2333, temp: 17, humidity: 31, cloudiness: 1, wind speed: 3.57
# 548: vila do maio lat: 15.1333, temp: 21, humidity: 73, cloudiness: 20, wind speed: 7.2
# 549: awjilah lat: 29.1081, temp: 24, humidity: 18, cloudiness: 100, wind speed: 5.79
# 550: nyurba lat: 63.2842, temp: -3, humidity: 93, cloudiness: 100, wind speed: 5.81
# 551: tambo lat: -14.8, temp: 5, humidity: 74, cloudiness: 44, wind speed: 5.02
# 552: kieta lat: -6.2167, temp: 26, humidity: 87, cloudiness: 99, wind speed: 2.63
# 553: talnakh lat: 69.4865, temp: -1, humidity: 95, cloudiness: 100, wind speed: 6.11
# 554: inhambane lat: -23.865, temp: 21, humidity: 76, cloudiness: 28, wind speed: 2.91
# 555: tall kayf lat: 37.0833, temp: 15, humidity: 51, cloudiness: 0, wind speed: 4.12
# 556: play cu lat: 37.0833, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 557: zhangye lat: 38.9342, temp: 14, humidity: 45, cloudiness: 3, wind speed: 2.69
# 558: narsaq lat: 60.9167, temp: 12, humidity: 26, cloudiness: 75, wind speed: 6.69
# 559: sogdiondon lat: 60.9167, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 560: luyang lat: 27.6239, temp: 19, humidity: 95, cloudiness: 98, wind speed: 1.51
# 561: aginskoye lat: 51.1, temp: -1, humidity: 49, cloudiness: 100, wind speed: 3.83
# 562: coihaique lat: -45.5752, temp: 10, humidity: 71, cloudiness: 75, wind speed: 1.75
# 563: santa maria lat: -29.6842, temp: 23, humidity: 53, cloudiness: 0, wind speed: 3.6
# 564: monrovia lat: 6.3005, temp: 25, humidity: 94, cloudiness: 75, wind speed: 8.23
# 565: yanam lat: 16.7333, temp: 26, humidity: 88, cloudiness: 78, wind speed: 1.66
# 566: swan hill lat: -35.3378, temp: 14, humidity: 68, cloudiness: 78, wind speed: 2.25
# 567: abu samrah lat: 35.3029, temp: 14, humidity: 40, cloudiness: 0, wind speed: 2.5
# 568: matagami lat: 49.7502, temp: 2, humidity: 48, cloudiness: 40, wind speed: 5.66
# 569: alihe lat: 50.5667, temp: 2, humidity: 43, cloudiness: 100, wind speed: 3.17
# 570: kununurra lat: -15.7667, temp: 21, humidity: 64, cloudiness: 100, wind speed: 1.54
# 571: mariental lat: -24.6333, temp: 21, humidity: 27, cloudiness: 38, wind speed: 5.12
# 572: beringovskiy lat: 63.05, temp: -5, humidity: 76, cloudiness: 48, wind speed: 3.63
# 573: payo lat: -3.7508, temp: 22, humidity: 98, cloudiness: 100, wind speed: 0.72
# 574: glossop lat: 53.4432, temp: 8, humidity: 59, cloudiness: 15, wind speed: 1.32
# 575: joao camara lat: -5.5375, temp: 27, humidity: 78, cloudiness: 40, wind speed: 5.14
# 576: muzaffarabad lat: 34.37, temp: 13, humidity: 85, cloudiness: 98, wind speed: 2.96
# 577: leshukonskoye lat: 64.8989, temp: 2, humidity: 94, cloudiness: 100, wind speed: 3.66
# 578: lola lat: 7.8, temp: 22, humidity: 89, cloudiness: 97, wind speed: 1.08
# 579: rochelle lat: 46.25, temp: 15, humidity: 55, cloudiness: 0, wind speed: 4.63
# 580: hami lat: 42.8, temp: 7, humidity: 33, cloudiness: 98, wind speed: 5.91
# 581: matamoros lat: 25.5333, temp: 34, humidity: 6, cloudiness: 75, wind speed: 4.3
# 582: inuvik lat: 68.3499, temp: -7, humidity: 63, cloudiness: 36, wind speed: 3.09
# 583: quatre cocos lat: -20.2078, temp: 25, humidity: 94, cloudiness: 75, wind speed: 2.57
# 584: santa isabel lat: -23.3156, temp: 18, humidity: 82, cloudiness: 20, wind speed: 3.09
# 585: deputatskiy lat: 69.3, temp: -16, humidity: 95, cloudiness: 94, wind speed: 0.65
# 586: ixtapa lat: 20.7, temp: 27, humidity: 74, cloudiness: 75, wind speed: 5.14
# 587: ayagoz lat: 47.9714, temp: -4, humidity: 69, cloudiness: 11, wind speed: 4.79
# 588: saint-augustin lat: 51.226, temp: 4, humidity: 91, cloudiness: 100, wind speed: 13.59
# 589: cruz alta lat: -28.6386, temp: 25, humidity: 44, cloudiness: 0, wind speed: 2.06
# 590: lahaina lat: 20.8783, temp: 27, humidity: 54, cloudiness: 40, wind speed: 10.29
# 591: garcina lat: 20.8783, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 592: ust-bolsheretsk lat: 20.8783, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 593: umm durman lat: 20.8783, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 594: cananeia lat: -25.0147, temp: 20, humidity: 81, cloudiness: 5, wind speed: 2.46
# 595: san andres lat: 12.5847, temp: 30, humidity: 66, cloudiness: 40, wind speed: 6.17
# 596: tyumentsevo lat: 53.3224, temp: -2, humidity: 81, cloudiness: 4, wind speed: 4.17
# 597: roebourne lat: -20.7833, temp: 24, humidity: 28, cloudiness: 0, wind speed: 5.35
# 598: machalpur lat: 24.1333, temp: 28, humidity: 19, cloudiness: 0, wind speed: 1.59
# 599: kaohsiung lat: 22.6163, temp: 23, humidity: 83, cloudiness: 40, wind speed: 2.57
# 600: plettenberg bay lat: -34.0527, temp: 19, humidity: 81, cloudiness: 1, wind speed: 3.31
# 601: mabama lat: -5.1333, temp: 19, humidity: 88, cloudiness: 40, wind speed: 1.64
# 602: pauini lat: -7.7136, temp: 25, humidity: 94, cloudiness: 80, wind speed: 0.73
# 603: huarmey lat: -10.0681, temp: 22, humidity: 77, cloudiness: 6, wind speed: 5.03
# 604: baiyin lat: 36.5583, temp: 9, humidity: 76, cloudiness: 0, wind speed: 1
# 605: kegayli lat: 36.5583, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 606: ambanja lat: -13.6833, temp: 24, humidity: 85, cloudiness: 100, wind speed: 1.13
# 607: pindamonhangaba lat: -22.9239, temp: 20, humidity: 68, cloudiness: 75, wind speed: 1.54
# 608: kenai lat: 60.5544, temp: 9, humidity: 49, cloudiness: 1, wind speed: 4.12
# 609: krasnoselkup lat: 65.7, temp: -5, humidity: 91, cloudiness: 84, wind speed: 6.11
# 610: mirabad lat: 30.4362, temp: 23, humidity: 12, cloudiness: 0, wind speed: 9.18
# 611: bumba lat: 2.1833, temp: 24, humidity: 78, cloudiness: 47, wind speed: 0.53
# 612: barguzin lat: 53.6167, temp: -5, humidity: 65, cloudiness: 77, wind speed: 1.21
# 613: san quintin lat: 30.4833, temp: 17, humidity: 61, cloudiness: 37, wind speed: 7.5
# 614: nouadhibou lat: 20.931, temp: 18, humidity: 88, cloudiness: 0, wind speed: 7.2
# 615: beloha lat: -25.1667, temp: 21, humidity: 80, cloudiness: 46, wind speed: 7.35
# 616: necochea lat: -38.5473, temp: 16, humidity: 86, cloudiness: 100, wind speed: 0.45
# 617: gazojak lat: 41.1875, temp: 14, humidity: 22, cloudiness: 100, wind speed: 6.05
# 618: sarishabari lat: 24.7333, temp: 25, humidity: 66, cloudiness: 23, wind speed: 0.56
# 619: northam lat: 51.0333, temp: 7, humidity: 74, cloudiness: 0, wind speed: 3.58
# 620: darhan lat: 49.4867, temp: -3, humidity: 82, cloudiness: 100, wind speed: 5.36
# 621: jay lat: 44.5039, temp: 0, humidity: 54, cloudiness: 100, wind speed: 5.36
# 622: aswan lat: 24.0934, temp: 31, humidity: 16, cloudiness: 47, wind speed: 4.56
# 623: priyutnoye lat: 46.1011, temp: 11, humidity: 94, cloudiness: 100, wind speed: 2.92
# 624: granja lat: -3.1203, temp: 24, humidity: 92, cloudiness: 47, wind speed: 1.36
# 625: daru lat: -9.0763, temp: 27, humidity: 83, cloudiness: 38, wind speed: 1.68
# 626: saint-pierre lat: -21.3393, temp: 23, humidity: 78, cloudiness: 90, wind speed: 8.23
# 627: husavik lat: 66.0449, temp: 4, humidity: 87, cloudiness: 0, wind speed: 3.09
# 628: west wendover lat: 40.7391, temp: 18, humidity: 11, cloudiness: 1, wind speed: 5.14
# 629: lata lat: 40.1629, temp: 13, humidity: 88, cloudiness: 0, wind speed: 1.03
# 630: sampit lat: -2.5333, temp: 23, humidity: 92, cloudiness: 97, wind speed: 0.43
# 631: santa isabel do rio negro lat: -0.4139, temp: 25, humidity: 92, cloudiness: 83, wind speed: 1.17
# 632: iwanai lat: 42.9744, temp: 8, humidity: 59, cloudiness: 0, wind speed: 0.77
# 633: marsa matruh lat: 31.3525, temp: 16, humidity: 72, cloudiness: 75, wind speed: 2.57
# 634: zakamensk lat: 50.3741, temp: -6, humidity: 88, cloudiness: 100, wind speed: 0.71
# 635: phrai bung lat: 50.3741, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 636: waipawa lat: -41.4122, temp: 16, humidity: 72, cloudiness: 20, wind speed: 8.23
# 637: ahipara lat: -35.1667, temp: 19, humidity: 76, cloudiness: 98, wind speed: 3.42
# 638: votkinsk lat: 57.0486, temp: 4, humidity: 87, cloudiness: 100, wind speed: 1.34
# 639: kautokeino lat: 69.0125, temp: -10, humidity: 87, cloudiness: 100, wind speed: 1.88
# 640: amga lat: 60.8953, temp: -8, humidity: 83, cloudiness: 55, wind speed: 1.79
# 641: vila lat: 42.0304, temp: 12, humidity: 89, cloudiness: 77, wind speed: 1.84
# 642: yar-sale lat: 66.8333, temp: 1, humidity: 87, cloudiness: 79, wind speed: 7.45
# 643: yongchang lat: 30.0381, temp: 19, humidity: 91, cloudiness: 100, wind speed: 1.08

# %%
#Build a new data frame with with weather data

weather_data_df = pd.DataFrame({"City" : clean_initial_city_list_df['Cities'],
                                "Latitude": lats,
                                "Degrees From Equator": list(map(abs, lats)),   # The intention of the 'Degrees from 
                                "Temperature" : temps,                          # Equator' column isto establish an 
                                "Humidity" : humids,                            # absolute value of the latitude, or 
                                "Cloudiness" : cloudies,                        # basically the distance from equator 
                                "Wind Speed" : wind_speeds                      # This will come in handy later for 
                              })                                                # plotting 

count1 = len(weather_data_df)                                                   # Count cities in dataframe  
print(f"Number of cities in dataframe: {count1}")                               # Print count 
weather_data_df.head()                                                          # Show the head sample
# Out:
# Number of cities in dataframe: 643
#              City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0          albany   42.6001               42.6001          5.0      34.0
# 1        bilibino   68.0546               68.0546         -6.0      84.0
# 2            hilo   19.7297               19.7297         25.0      51.0
# 3  ribeira grande   38.5167               38.5167         14.0      78.0
# 4      nikolskoye   59.7035               59.7035          7.0      93.0
#
#    Cloudiness  Wind Speed
# 0        86.0        6.42
# 1        98.0        1.50
# 2        75.0        3.60
# 3        60.0       16.78
# 4        90.0        1.00

# %%
# Remove cities with missing weather data from dataframe and save the data in a .csv file

clean_weather_data_df= weather_data_df.dropna(how='any')          # Use .dropna() to remove rows with missing data


clean_weather_data_df.to_csv("weather-data.csv", index=False)     # Save the dataframe above to .csv file

count2 = len(clean_weather_data_df)                               # Get a new city count
print(f"{count1 - count2} cities were removed. Number of cities in cleaned dataframe: {count2}") #Print the updated count
clean_weather_data_df.head()                                      # Show the head sample
# Out:
# 45 cities were removed. Number of cities in cleaned dataframe: 598
#              City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0          albany   42.6001               42.6001          5.0      34.0
# 1        bilibino   68.0546               68.0546         -6.0      84.0
# 2            hilo   19.7297               19.7297         25.0      51.0
# 3  ribeira grande   38.5167               38.5167         14.0      78.0
# 4      nikolskoye   59.7035               59.7035          7.0      93.0
#
#    Cloudiness  Wind Speed
# 0        86.0        6.42
# 1        98.0        1.50
# 2        75.0        3.60
# 3        60.0       16.78
# 4        90.0        1.00

# %%
# Set up some basic plt formatting configurations

plt.rc('font', size=12)
plt.rc('axes', labelsize=15)
plt.rc('axes', titlesize=20)

# Create a function to match labels to a the correlation r coefficients. This will come in handy below 

def r_label(r):
    abs_r = abs(r)
    if abs_r >= .8 : return "Very Strong"
    elif abs_r >= .6 : return "Strong"
    elif abs_r >= .4: return "Moderate"
    elif abs_r >= .2: return "Low"
    else: return "Negligible"

# Set up list of variables to compare with latitude. This gets plugged into a for loop in the following sections

master_plot_list = ["Temperature", "Humidity", "Cloudiness", "Wind Speed"]

# %%
                # PLOTTING WEATHER CONDITIONS VS. LATITUDE USING A FOR LOOP   

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, sharey='row', figsize=(15,12))    # Set up figure for subplots

plot_list = [ax0, ax1, ax2, ax3]                                # Set up list of plots to help with the for loop below

plt.subplots_adjust(hspace=.3, wspace=0.05)                     # Formatting        
fig.suptitle('WEATHER CONDITIONS VS LATITUDE', ha='center')     # Set title for the whole figure

fig.text(.08, .5, "Distance from Equator in Degrees",           # Set label for shared y axis. This seemed to be
         va='center', rotation='vertical', fontsize=20,         # the easiest way. 
         linespacing = 2)  

for i in range (4):                                             # Aaaaaand.Here.We.Go!

    x_axis_name = master_plot_list[i]                           # Set name of x axis for the sake of labels
    x_axis = clean_weather_data_df[x_axis_name]                 # Set up x axis values 
    y_axis = clean_weather_data_df["Degrees From Equator"]      # Set up y axis values 

    slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
    regress_values = x_axis * slope + intercept                 # Calculate regression values
              
    plot_list[i].set_xlabel(f"{x_axis_name}")                   # Set x axis label for subplot                  
    plot_list[i].set_title(f"{x_axis_name} vs. Latitude")       # Set title for subplot
    
    r = round(stats.pearsonr(x_axis, y_axis)[0],2)              # Calculate correlation coefficient
    rlabel = r_label(r)                                         # Call function to create a label for the r number

    plot_list[i].scatter(x_axis, y_axis, facecolors="darkred",  alpha=.5,     # Plot the scatter chart
                         label=f"{x_axis_name} r = {r} \nCorrelation is {rlabel}")   # and label it for the legend                                                

    plot_list[i].legend()                                        # Add the legend
    
    plot_list[i].plot(x_axis, regress_values, color="steelblue") # Plot the regression line
                                               
plt.savefig("weather-conditions-vs-latitude.png")                # Save the png file   

plt.show()

# %% [markdown]
#                                                     CONCLUSIONS
# As you can see from the charts above, the correlation between temperature and distance from the equator (i.e., positive and negative latitudes) is very strong, supporting the assertion that climates get warmer as you get closer to the equator.
#
# All other weather conditions (humidity, cloudiness and wind speed) have negligible correlations.

# %%
#Create new dataframes for the Northern and Southern Hemisphere cities

north_hem_df = clean_weather_data_df.loc[clean_weather_data_df['Latitude'] > 0, ].reset_index(drop=True)

south_hem_df = clean_weather_data_df.loc[clean_weather_data_df['Latitude'] <= 0, ].reset_index(drop=True)

south_hem_df.head()
# Out:
#            City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0        atuona   -9.8000                9.8000         27.0      75.0
# 1         vaini  -21.2000               21.2000         29.0      84.0
# 2     tuatapere  -46.1333               46.1333          9.0      98.0
# 3        viedma  -40.8135               40.8135         17.0      55.0
# 4  christchurch  -43.5333               43.5333         17.0      67.0
#
#    Cloudiness  Wind Speed
# 0        53.0        9.17
# 1        40.0        2.57
# 2        99.0        3.13
# 3        42.0        2.24
# 4        88.0        1.54

# %%
        # PLOTTING WEATHER CONDITIONS BY HEMISPHERE VS. LATITUDE USING A FOR LOOP

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, sharey='row', figsize=(15,15))    # Set up figure for subplots

plot_list = [ax0, ax1, ax2, ax3]                               # Set up list of plots to help with the for loop below

plt.subplots_adjust(hspace=.3, wspace=0.05)                    # Formatting
fig.suptitle('WEATHER CONDITIONS VS LATITUDE BY HEMISPHERE', ha='center') # Set title for the whole figure

fig.text(.08, 0.5, "Distance from Equator in Degrees",         # Set label for shared y axis. This seemed to be         
         va='center', rotation='vertical', fontsize=20)

for i in range (4):   

        # Northern Hemisphere
    north_x_axis_name = master_plot_list[i]                           # Set name of x axis for the sake of labels
    north_x_axis = north_hem_df[north_x_axis_name]                    # Set up x axis values 
    north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

    slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
    north_regress_values = north_x_axis * slope + intercept           # Calculate regression values

    north_r = round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)  # Calculate correlation coefficient
    north_r_label = r_label(north_r)                                  # Call function to create a label for the r number                                
    
        # Southern Hemisphere
    south_x_axis_name = master_plot_list[i]                           # Set name of x axis for the sake of labels
    south_x_axis = south_hem_df[south_x_axis_name]                    # Set up x axis values 
    south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 
    
    slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
    south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values   
    
    south_r = round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)  # Calculate correlation coefficient
    south_r_label = r_label(south_r)                                  # Call function to create a label for the r number
    
    # Formatting
    plot_list[i].set_xlabel(f"{north_x_axis_name}")                   # Set x axis label for subplot              
    plot_list[i].set_title(f"{north_x_axis_name} vs. Latitude by Hemisphere") # Set title for subplot 
     
        
    # Plotting
        # Northern Hemisphere
    plot_list[i].scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5,     # Plot the scatter chart
        label=f"N. Hemisphere {north_x_axis_name} r = {north_r} \nCorrelation is {north_r_label}")                                                  

    plot_list[i].plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line
    
        # Southern Hemisphere
    plot_list[i].scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5,   # Plot the scatter chart
        label=f"S. Hemisphere {south_x_axis_name} r = {south_r} \nCorrelation is {south_r_label}")                                                 

    plot_list[i].plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line    
       
    plot_list[i].legend(fontsize=10)                                   # Add the legend
    
plt.savefig("weather-conditions-vs-latitude-by-hemisphere.png")        # Save the png file   

plt.show()

# %% [markdown]
# This analysis by hemisphere doesn't change the initial results. Temperature is still the only weather variable that has a strong correlation to latitude, although on several random samples, the correlation is a little stronger in southern hemisphere compared to the north.

# %%
                                    # TEMPERATURE VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[0]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[0]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

plt.figure(figsize=(10, 7))                                       # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min()-2, north_x_axis.max()+2)              # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
     
# Plotting 

    # Northern Hemisphere
plt.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5) # Plot the scatter chart
plt.annotate(f"{north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}", # Plot the correlation coeficient
             (-7,26), fontsize=15, color="darkred")                                                   

plt.plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line

    # Southern Hemisphere
plt.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=1) # Plot the scatter chart
plt.annotate(f"{south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}", # Plot the correlation coeficient
             (-7,21), fontsize=15, color="steelblue")                                                   

plt.plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line



plt.show()

# %%
                                    # HUMIDITY VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[1]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[1]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

fig, ax = plt.subplots()                                          # Set up subplots to make the legend easier to create
fig.set_size_inches(10, 7)                                        # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min(), north_x_axis.max())                    # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
# Plotting 

    # Northern Hemisphere
ax.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5, label='Northern Hemisphere') # Plot the scatter chart
ax.annotate(f"{north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,26), fontsize=15, color="darkred")                                                   

ax.plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line

    # Southern Hemisphere
ax.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5, label='Southern Hemisphere') # Plot the scatter chart
ax.annotate(f"{south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,21), fontsize=15, color="steelblue")                                                   

ax.plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line

plt.legend()                                                           # Add the legend
plt.show()

# %%
                                    # CLOUDINESS VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[2]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[2]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

fig, ax = plt.subplots()                                          # Set up subplots to make the legend easier to create
fig.set_size_inches(10, 7)                                        # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min(), north_x_axis.max())                    # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
# Plotting 

    # Northern Hemisphere
ax.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5,  # Plot the scatter chart
           label=f"Northern Hemisphere: {north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}")                                                  

ax.plot(north_x_axis, north_regress_values, color="darkred")       # Plot the regression line

    # Southern Hemisphere
ax.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5, # Plot the scatter chart
           label=f"Southern Hemisphere: {south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}")                                                 

ax.plot(south_x_axis, south_regress_values, color="steelblue")     # Plot the regression line

plt.legend()                                                       # Add the legend
plt.show()

# %%
                                    # WIND SPEED VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[3]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[3]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

fig, ax = plt.subplots()                                          # Set up subplots to make the legend easier to create
fig.set_size_inches(10, 7)                                        # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min(), north_x_axis.max())                    # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
# Plotting 

    # Northern Hemisphere
ax.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5, label='Northern Hemisphere') # Plot the scatter chart
ax.annotate(f"{north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,26), fontsize=15, color="darkred")                                                   

ax.plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line

    # Southern Hemisphere
ax.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5, label='Southern Hemisphere') # Plot the scatter chart
ax.annotate(f"{south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,21), fontsize=15, color="steelblue")                                                   

ax.plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line

plt.legend()                                                           # Add the legend
plt.show()

# %%
                                            # TEMPERATURE VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[0]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating

plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                    
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (-7,21), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()

# %%
                                            # HUMIDITY VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[1]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating
plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                   
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (13,76), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()

# %%
                                        # CLOUDINESS VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[2]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating
 
plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                   
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (3,76), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()

# %%
                                            # WIND SPEED VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[3]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating

plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                    
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (9,21), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()
