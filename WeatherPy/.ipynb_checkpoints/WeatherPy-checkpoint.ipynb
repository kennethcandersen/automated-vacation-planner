# %%
#pip install citipy

# %%
from citipy import citipy
from random import uniform
import requests, json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

# %%
plt.rc('font', size=12)
plt.rc('axes', labelsize=15)
plt.rc('axes', titlesize=20)

# %%
cities = []
lats_random = []
for i in range(1, 5001):
    lat_coord  = round(uniform(-180,180), 2)
    long_coord = round(uniform(-90, 90), 2)
    city = citipy.nearest_city(lat_coord, long_coord).city_name
    cities.append(city)
    lats_random.append(lat_coord)
    #print (f"{i}: {city}")

# %%
initial_city_list_df = pd.DataFrame({"Cities" : cities})
clean_initial_city_list_df= initial_city_list_df.drop_duplicates(subset ="Cities",
                     keep = 'first').reset_index(drop=True)
clean_initial_city_list_df
# Out:
#             Cities
# 0            debno
# 1         orgovany
# 2          bubaque
# 3         sabzevar
# 4    teofilo otoni
# ..             ...
# 876       hemsedal
# 877    aberystwyth
# 878          altay
# 879     taguatinga
# 880         barbar
#
# [881 rows x 1 columns]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = 'dd74909c8156c984d600e5782436601a'
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info

lats = []
temps = []
humids = []
cloudies = []
wind_speeds = []

# Loop through the list of cities and perform a request for data on each
for city in clean_initial_city_list_df['Cities']:
    i = 1
    response = requests.get(query_url + city).json()
    try:
        lat = response['coord']['lat']
        temp = round(response['main']['temp'])
        humid = response['main']['humidity']
        cloud = response['clouds']['all']
        wind = response['wind']['speed']
    except KeyError:
        temp = np.nan
        humid = np.nan
        cloud = np.nan
        wind = np.nan
    lats.append(lat)
    temps.append(temp)
    humids.append(humid)
    cloudies.append(cloud)
    wind_speeds.append(wind)
    print (f"{i}: {city} lat: {lat}, temp: {temp}, humidity: {humid}, cloudiness: {cloud}, wind speed: {wind}")
    i+=1
#print (response)
# Out:
# 1: debno lat: 52.739, temp: 7, humidity: 68, cloudiness: 51, wind speed: 0.89
# 1: orgovany lat: 46.7509, temp: 12, humidity: 76, cloudiness: 0, wind speed: 3.09
# 1: bubaque lat: 11.2833, temp: 26, humidity: 68, cloudiness: 48, wind speed: 7.5
# 1: sabzevar lat: 36.2126, temp: 22, humidity: 27, cloudiness: 7, wind speed: 5.48
# 1: teofilo otoni lat: -17.8575, temp: 27, humidity: 58, cloudiness: 28, wind speed: 0.84
# 1: sur lat: 22.5667, temp: 31, humidity: 31, cloudiness: 32, wind speed: 4.02
# 1: ustrzyki dolne lat: 49.4304, temp: 1, humidity: 100, cloudiness: 100, wind speed: 1.79
# 1: ushuaia lat: -54.8, temp: 8, humidity: 87, cloudiness: 90, wind speed: 1.54
# 1: formoso do araguaia lat: -54.8, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: bredasdorp lat: -34.5322, temp: 15, humidity: 94, cloudiness: 6, wind speed: 2.57
# 1: hithadhoo lat: -0.6, temp: 28, humidity: 72, cloudiness: 74, wind speed: 3.45
# 1: lienz lat: 46.8289, temp: 6, humidity: 40, cloudiness: 75, wind speed: 2.3
# 1: longyearbyen lat: 78.2186, temp: -8, humidity: 73, cloudiness: 75, wind speed: 3.09
# 1: castro lat: -24.7911, temp: 18, humidity: 71, cloudiness: 85, wind speed: 0.8
# 1: dingle lat: 10.9995, temp: 25, humidity: 86, cloudiness: 49, wind speed: 2.78
# 1: bukan lat: 36.521, temp: 17, humidity: 54, cloudiness: 98, wind speed: 2.78
# 1: robe lat: -37.1833, temp: 15, humidity: 71, cloudiness: 77, wind speed: 6.86
# 1: tombouctou lat: 20, temp: 37, humidity: 7, cloudiness: 77, wind speed: 3.7
# 1: belushya guba lat: 20, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: taolanaro lat: 20, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: husavik lat: 66.0449, temp: 5, humidity: 81, cloudiness: 0, wind speed: 4.12
# 1: ilulissat lat: 69.2167, temp: -1, humidity: 64, cloudiness: 75, wind speed: 2.57
# 1: illoqqortoormiut lat: 69.2167, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: podporozhye lat: 60.9112, temp: 4, humidity: 93, cloudiness: 70, wind speed: 2.17
# 1: port alfred lat: -33.5906, temp: 21, humidity: 80, cloudiness: 26, wind speed: 9.01
# 1: port elizabeth lat: -33.918, temp: 19, humidity: 88, cloudiness: 0, wind speed: 7.2
# 1: terra santa lat: -2.1042, temp: 31, humidity: 61, cloudiness: 74, wind speed: 1.26
# 1: barentsburg lat: -2.1042, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: albany lat: 42.6001, temp: 5, humidity: 39, cloudiness: 98, wind speed: 0.89
# 1: linden lat: 6, temp: 31, humidity: 62, cloudiness: 40, wind speed: 7.2
# 1: qaanaaq lat: 77.484, temp: -5, humidity: 80, cloudiness: 100, wind speed: 3.49
# 1: gaeta lat: 41.2183, temp: 12, humidity: 95, cloudiness: 99, wind speed: 0.45
# 1: dikson lat: 73.5069, temp: 0, humidity: 90, cloudiness: 96, wind speed: 9.33
# 1: dehri lat: 24.8667, temp: 29, humidity: 30, cloudiness: 100, wind speed: 1.06
# 1: oranjemund lat: -28.55, temp: 16, humidity: 86, cloudiness: 1, wind speed: 1.38
# 1: lagoa lat: 39.05, temp: 14, humidity: 78, cloudiness: 85, wind speed: 18.17
# 1: hermanus lat: -34.4187, temp: 19, humidity: 74, cloudiness: 19, wind speed: 3.39
# 1: crateus lat: -5.1783, temp: 29, humidity: 65, cloudiness: 59, wind speed: 2.48
# 1: iqaluit lat: 63.7506, temp: -7, humidity: 79, cloudiness: 90, wind speed: 1.54
# 1: nouadhibou lat: 20.931, temp: 21, humidity: 68, cloudiness: 0, wind speed: 10.8
# 1: bambous virieux lat: -20.3428, temp: 26, humidity: 89, cloudiness: 75, wind speed: 4.63
# 1: georgetown lat: 5.4112, temp: 26, humidity: 94, cloudiness: 40, wind speed: 2.28
# 1: totness lat: 5.8833, temp: 27, humidity: 85, cloudiness: 26, wind speed: 5.89
# 1: belousovka lat: 50.1339, temp: -2, humidity: 69, cloudiness: 87, wind speed: 4
# 1: vardo lat: 70.3705, temp: 1, humidity: 93, cloudiness: 75, wind speed: 8.75
# 1: athens lat: 37.9795, temp: 18, humidity: 42, cloudiness: 20, wind speed: 2.57
# 1: bahia blanca lat: -38.7196, temp: 23, humidity: 39, cloudiness: 1, wind speed: 2.62
# 1: honningsvag lat: 70.9821, temp: 0, humidity: 93, cloudiness: 90, wind speed: 2.06
# 1: kedrovyy lat: 56.1667, temp: -5, humidity: 68, cloudiness: 0, wind speed: 1
# 1: gaya lat: 24.7833, temp: 27, humidity: 57, cloudiness: 75, wind speed: 1.67
# 1: attawapiskat lat: 24.7833, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: wukari lat: 7.85, temp: 32, humidity: 48, cloudiness: 97, wind speed: 1.92
# 1: bazaliya lat: 49.7127, temp: 6, humidity: 92, cloudiness: 97, wind speed: 7.84
# 1: pestovo lat: 58.5938, temp: 7, humidity: 79, cloudiness: 74, wind speed: 2.6
# 1: comodoro rivadavia lat: -45.8667, temp: 13, humidity: 50, cloudiness: 75, wind speed: 3.09
# 1: unecha lat: 52.8459, temp: 9, humidity: 82, cloudiness: 75, wind speed: 4.61
# 1: le port lat: -20.9373, temp: 23, humidity: 83, cloudiness: 75, wind speed: 7.72
# 1: rybnaya sloboda lat: 55.4613, temp: 8, humidity: 81, cloudiness: 0, wind speed: 4
# 1: mrirt lat: 55.4613, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: san cristobal lat: 7.7669, temp: 32, humidity: 55, cloudiness: 20, wind speed: 5.66
# 1: arona lat: 28.0996, temp: 21, humidity: 56, cloudiness: 20, wind speed: 6.17
# 1: kamenka lat: 51.3223, temp: 10, humidity: 76, cloudiness: 90, wind speed: 2.07
# 1: jamestown lat: 42.097, temp: 2, humidity: 55, cloudiness: 90, wind speed: 9.77
# 1: pangnirtung lat: 66.1451, temp: -6, humidity: 79, cloudiness: 90, wind speed: 1.54
# 1: beloha lat: -25.1667, temp: 21, humidity: 78, cloudiness: 12, wind speed: 8.2
# 1: lusambo lat: -4.9667, temp: 24, humidity: 76, cloudiness: 64, wind speed: 1.03
# 1: namibe lat: -15.1961, temp: 27, humidity: 81, cloudiness: 14, wind speed: 3.09
# 1: bathsheba lat: 13.2167, temp: 29, humidity: 58, cloudiness: 40, wind speed: 9.26
# 1: marcona lat: 13.2167, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: muros lat: 42.7762, temp: 17, humidity: 70, cloudiness: 74, wind speed: 2.09
# 1: east london lat: -33.0153, temp: 19, humidity: 88, cloudiness: 40, wind speed: 2.06
# 1: lere lat: 10.387, temp: 32, humidity: 30, cloudiness: 81, wind speed: 3.78
# 1: mahebourg lat: -20.4081, temp: 26, humidity: 89, cloudiness: 75, wind speed: 4.63
# 1: codrington lat: -38.2667, temp: 13, humidity: 78, cloudiness: 75, wind speed: 4.67
# 1: ribeira grande lat: 38.5167, temp: 15, humidity: 82, cloudiness: 40, wind speed: 11.32
# 1: ciudad guayana lat: 8.3533, temp: 32, humidity: 63, cloudiness: 70, wind speed: 1.79
# 1: hamilton lat: 39.1834, temp: 10, humidity: 37, cloudiness: 75, wind speed: 5.14
# 1: nanortalik lat: 60.1432, temp: 4, humidity: 69, cloudiness: 97, wind speed: 1.39
# 1: les cayes lat: 18.2, temp: 30, humidity: 55, cloudiness: 27, wind speed: 5.82
# 1: zaozerne lat: 45.1582, temp: 11, humidity: 66, cloudiness: 3, wind speed: 4.9
# 1: nisia floresta lat: -6.0911, temp: 30, humidity: 70, cloudiness: 75, wind speed: 5.66
# 1: touros lat: -5.1989, temp: 29, humidity: 70, cloudiness: 40, wind speed: 7.2
# 1: atar lat: 20.5169, temp: 36, humidity: 23, cloudiness: 0, wind speed: 1.03
# 1: cape town lat: -33.9258, temp: 17, humidity: 88, cloudiness: 0, wind speed: 3.6
# 1: busselton lat: -33.65, temp: 14, humidity: 78, cloudiness: 100, wind speed: 1.34
# 1: araouane lat: 18.9048, temp: 37, humidity: 8, cloudiness: 65, wind speed: 2.3
# 1: saint george lat: 37.1041, temp: 21, humidity: 24, cloudiness: 1, wind speed: 3.6
# 1: hofn lat: 64.2539, temp: 4, humidity: 77, cloudiness: 78, wind speed: 5.1
# 1: oriximina lat: -1.7656, temp: 31, humidity: 63, cloudiness: 68, wind speed: 0.41
# 1: nyuksenitsa lat: 60.4128, temp: 5, humidity: 84, cloudiness: 95, wind speed: 4.63
# 1: narsaq lat: 60.9167, temp: 12, humidity: 28, cloudiness: 40, wind speed: 7.2
# 1: arraial do cabo lat: -22.9661, temp: 24, humidity: 78, cloudiness: 20, wind speed: 9.26
# 1: caravelas lat: -17.7125, temp: 27, humidity: 70, cloudiness: 93, wind speed: 2.77
# 1: sao filipe lat: 14.8961, temp: 23, humidity: 72, cloudiness: 97, wind speed: 4.22
# 1: sechura lat: -5.5569, temp: 27, humidity: 56, cloudiness: 14, wind speed: 5.51
# 1: vestmannaeyjar lat: 63.4427, temp: 8, humidity: 76, cloudiness: 90, wind speed: 8.75
# 1: upernavik lat: 72.7868, temp: -2, humidity: 80, cloudiness: 100, wind speed: 5.17
# 1: beisfjord lat: 68.3751, temp: 2, humidity: 64, cloudiness: 90, wind speed: 5.66
# 1: leh lat: 34.1667, temp: -2, humidity: 63, cloudiness: 78, wind speed: 2.91
# 1: benguela lat: -12.5763, temp: 28, humidity: 84, cloudiness: 99, wind speed: 2.36
# 1: tete lat: -16.1564, temp: 26, humidity: 65, cloudiness: 75, wind speed: 2.06
# 1: grindavik lat: 63.8424, temp: 8, humidity: 87, cloudiness: 75, wind speed: 13.38
# 1: souillac lat: -20.5167, temp: 26, humidity: 89, cloudiness: 75, wind speed: 4.63
# 1: ambovombe lat: -25.1667, temp: 22, humidity: 80, cloudiness: 11, wind speed: 8.45
# 1: pisco lat: -13.7, temp: 20, humidity: 77, cloudiness: 0, wind speed: 4.12
# 1: gat lat: 31.61, temp: 17, humidity: 32, cloudiness: 3, wind speed: 0.89
# 1: thinadhoo lat: 0.5333, temp: 29, humidity: 63, cloudiness: 95, wind speed: 4.3
# 1: plesetsk lat: 62.708, temp: 2, humidity: 88, cloudiness: 100, wind speed: 3.71
# 1: changji lat: 44.0167, temp: 5, humidity: 52, cloudiness: 0, wind speed: 2
# 1: krasnaya gora lat: 52.9995, temp: 10, humidity: 87, cloudiness: 75, wind speed: 4
# 1: cidreira lat: -30.1811, temp: 22, humidity: 65, cloudiness: 3, wind speed: 6.42
# 1: punta arenas lat: -53.15, temp: 10, humidity: 81, cloudiness: 75, wind speed: 2.06
# 1: grand-santi lat: 4.25, temp: 27, humidity: 89, cloudiness: 74, wind speed: 1.87
# 1: leshukonskoye lat: 64.8989, temp: 5, humidity: 81, cloudiness: 100, wind speed: 4.97
# 1: safaga lat: 26.7292, temp: 27, humidity: 34, cloudiness: 59, wind speed: 9.26
# 1: ndouci lat: 26.7292, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: los llanos de aridane lat: 28.6585, temp: 19, humidity: 68, cloudiness: 75, wind speed: 1.03
# 1: mar del plata lat: -38.0023, temp: 22, humidity: 73, cloudiness: 75, wind speed: 3.6
# 1: salalah lat: 17.0151, temp: 28, humidity: 69, cloudiness: 0, wind speed: 1.54
# 1: barcelos lat: 41.5388, temp: 17, humidity: 72, cloudiness: 20, wind speed: 1.54
# 1: parrita lat: 9.5201, temp: 24, humidity: 68, cloudiness: 20, wind speed: 8.75
# 1: dagda lat: 56.0951, temp: 4, humidity: 74, cloudiness: 100, wind speed: 3.1
# 1: lipari lat: 38.4674, temp: 17, humidity: 74, cloudiness: 100, wind speed: 3.58
# 1: jalu lat: 29.0331, temp: 26, humidity: 14, cloudiness: 90, wind speed: 4.53
# 1: westport lat: 41.1415, temp: 8, humidity: 29, cloudiness: 75, wind speed: 8.75
# 1: coihaique lat: -45.5752, temp: 11, humidity: 71, cloudiness: 75, wind speed: 1.54
# 1: pushkino lat: 56.0172, temp: 8, humidity: 87, cloudiness: 0, wind speed: 4
# 1: diamantino lat: -14.4086, temp: 32, humidity: 36, cloudiness: 17, wind speed: 1.11
# 1: winneba lat: 5.3511, temp: 30, humidity: 74, cloudiness: 0, wind speed: 6.17
# 1: suda lat: 59.1525, temp: 4, humidity: 93, cloudiness: 20, wind speed: 1
# 1: saint-philippe lat: -21.3585, temp: 23, humidity: 78, cloudiness: 75, wind speed: 9.26
# 1: ostrovnoy lat: 68.0531, temp: 1, humidity: 85, cloudiness: 98, wind speed: 4.97
# 1: ambilobe lat: -13.2, temp: 24, humidity: 84, cloudiness: 100, wind speed: 1.82
# 1: grand river south east lat: -13.2, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: alizai lat: 33.5383, temp: 18, humidity: 52, cloudiness: 1, wind speed: 1.37
# 1: mezhdurechensk lat: 53.6942, temp: -4, humidity: 88, cloudiness: 19, wind speed: 1.57
# 1: amderma lat: 53.6942, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: verkhnyaya inta lat: 65.9811, temp: 4, humidity: 85, cloudiness: 100, wind speed: 7.43
# 1: tasiilaq lat: 65.6145, temp: -1, humidity: 43, cloudiness: 90, wind speed: 7.2
# 1: harper lat: 4.375, temp: 29, humidity: 76, cloudiness: 52, wind speed: 5.03
# 1: mezhdurechenskiy lat: 59.6, temp: 8, humidity: 63, cloudiness: 71, wind speed: 5.32
# 1: tumannyy lat: 59.6, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: minab lat: 27.1467, temp: 28, humidity: 69, cloudiness: 76, wind speed: 4.12
# 1: pimentel lat: -6.8367, temp: 23, humidity: 57, cloudiness: 0, wind speed: 8.75
# 1: lebu lat: -37.6167, temp: 14, humidity: 59, cloudiness: 19, wind speed: 3.15
# 1: lahij lat: 13.1667, temp: 26, humidity: 42, cloudiness: 18, wind speed: 1.97
# 1: buena vista lat: 43.4203, temp: 8, humidity: 36, cloudiness: 75, wind speed: 6.17
# 1: mocuba lat: -16.8392, temp: 21, humidity: 93, cloudiness: 76, wind speed: 1.51
# 1: buraydah lat: 26.326, temp: 31, humidity: 18, cloudiness: 0, wind speed: 3.6
# 1: dahanu lat: 19.9667, temp: 28, humidity: 72, cloudiness: 97, wind speed: 2.74
# 1: necochea lat: -38.5473, temp: 19, humidity: 67, cloudiness: 98, wind speed: 2.35
# 1: gafanha da encarnacao lat: 40.6181, temp: 18, humidity: 77, cloudiness: 20, wind speed: 1.54
# 1: bonavista lat: 48.6499, temp: 10, humidity: 47, cloudiness: 84, wind speed: 4.12
# 1: akdepe lat: 42.0551, temp: 15, humidity: 23, cloudiness: 0, wind speed: 6.17
# 1: bathurst lat: -33.4166, temp: 2, humidity: 90, cloudiness: 4, wind speed: 1.15
# 1: taoudenni lat: 22.6783, temp: 39, humidity: 6, cloudiness: 0, wind speed: 5
# 1: raudeberg lat: 61.9875, temp: 3, humidity: 83, cloudiness: 100, wind speed: 6.04
# 1: mariakani lat: -3.8633, temp: 25, humidity: 82, cloudiness: 100, wind speed: 3.61
# 1: rawson lat: -43.3002, temp: 15, humidity: 44, cloudiness: 92, wind speed: 6.74
# 1: kastamonu lat: 41.5, temp: 7, humidity: 78, cloudiness: 40, wind speed: 1.01
# 1: kharp lat: 66.8014, temp: 2, humidity: 99, cloudiness: 100, wind speed: 1.57
# 1: wageningen lat: 51.9667, temp: 9, humidity: 57, cloudiness: 49, wind speed: 4.63
# 1: parfino lat: 57.9731, temp: 9, humidity: 73, cloudiness: 90, wind speed: 1.97
# 1: yanam lat: 16.7333, temp: 27, humidity: 83, cloudiness: 71, wind speed: 1.51
# 1: vila franca do campo lat: 37.7167, temp: 16, humidity: 77, cloudiness: 75, wind speed: 14.92
# 1: bilma lat: 18.6853, temp: 35, humidity: 10, cloudiness: 13, wind speed: 2.7
# 1: kruisfontein lat: -34.0033, temp: 19, humidity: 81, cloudiness: 1, wind speed: 1.79
# 1: praia lat: 14.9215, temp: 24, humidity: 60, cloudiness: 75, wind speed: 9.26
# 1: atasu lat: 48.6814, temp: 2, humidity: 43, cloudiness: 4, wind speed: 5.5
# 1: saint-pierre lat: -21.3393, temp: 24, humidity: 78, cloudiness: 75, wind speed: 9.26
# 1: valkla lat: 59.4744, temp: 5, humidity: 75, cloudiness: 40, wind speed: 1.03
# 1: uglyanets lat: 51.8191, temp: 11, humidity: 54, cloudiness: 0, wind speed: 2
# 1: mehamn lat: 71.0357, temp: 2, humidity: 75, cloudiness: 40, wind speed: 7.2
# 1: torbay lat: 47.6666, temp: 8, humidity: 46, cloudiness: 90, wind speed: 10.8
# 1: sinnamary lat: 5.3833, temp: 27, humidity: 87, cloudiness: 71, wind speed: 5.92
# 1: verkhnetulomskiy lat: 68.6073, temp: 1, humidity: 100, cloudiness: 75, wind speed: 2
# 1: antalaha lat: -14.9003, temp: 24, humidity: 89, cloudiness: 93, wind speed: 3.71
# 1: kanniyakumari lat: 8.0833, temp: 28, humidity: 78, cloudiness: 21, wind speed: 6.2
# 1: rio grande lat: -32.035, temp: 25, humidity: 53, cloudiness: 20, wind speed: 11.32
# 1: viedma lat: -40.8135, temp: 19, humidity: 51, cloudiness: 99, wind speed: 4.05
# 1: adrar lat: 20.5022, temp: 34, humidity: 6, cloudiness: 0, wind speed: 4.08
# 1: victoria lat: 22.2855, temp: 24, humidity: 84, cloudiness: 0, wind speed: 3.79
# 1: joao pinheiro lat: -17.7425, temp: 29, humidity: 29, cloudiness: 0, wind speed: 2.83
# 1: ler lat: 8.3018, temp: 27, humidity: 61, cloudiness: 99, wind speed: 2.25
# 1: bandarbeyla lat: 9.4942, temp: 29, humidity: 74, cloudiness: 32, wind speed: 4.36
# 1: affery lat: 6.315, temp: 29, humidity: 71, cloudiness: 85, wind speed: 1.68
# 1: vila velha lat: -20.3297, temp: 27, humidity: 73, cloudiness: 20, wind speed: 5.14
# 1: kattivakkam lat: 13.2167, temp: 29, humidity: 79, cloudiness: 40, wind speed: 4.12
# 1: salinopolis lat: -0.6136, temp: 25, humidity: 87, cloudiness: 100, wind speed: 2.68
# 1: nova olimpia lat: -14.7972, temp: 34, humidity: 35, cloudiness: 10, wind speed: 1.07
# 1: banda aceh lat: 5.5577, temp: 27, humidity: 78, cloudiness: 100, wind speed: 4.2
# 1: hatillo lat: 18.4863, temp: 29, humidity: 65, cloudiness: 40, wind speed: 6.69
# 1: chuy lat: -33.6971, temp: 23, humidity: 54, cloudiness: 13, wind speed: 6.01
# 1: tabou lat: 4.423, temp: 29, humidity: 75, cloudiness: 30, wind speed: 4.93
# 1: tiko lat: 4.0745, temp: 28, humidity: 84, cloudiness: 82, wind speed: 3.46
# 1: torrijos lat: 39.9819, temp: 16, humidity: 67, cloudiness: 20, wind speed: 2.06
# 1: lyaskelya lat: 61.7667, temp: 2, humidity: 97, cloudiness: 52, wind speed: 1.78
# 1: kaoma lat: -14.7833, temp: 20, humidity: 58, cloudiness: 13, wind speed: 2.18
# 1: yar-sale lat: 66.8333, temp: 2, humidity: 92, cloudiness: 100, wind speed: 8.76
# 1: shawville lat: 45.6001, temp: 6, humidity: 46, cloudiness: 100, wind speed: 7.51
# 1: digri lat: 25.1558, temp: 30, humidity: 48, cloudiness: 1, wind speed: 7.8
# 1: trairi lat: -3.2778, temp: 29, humidity: 70, cloudiness: 27, wind speed: 3.72
# 1: saurimo lat: -9.6608, temp: 20, humidity: 89, cloudiness: 88, wind speed: 1.66
# 1: aflu lat: -9.6608, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: ondjiva lat: -17.0667, temp: 23, humidity: 32, cloudiness: 53, wind speed: 2.77
# 1: sume lat: -7.6717, temp: 31, humidity: 43, cloudiness: 54, wind speed: 1.29
# 1: puerto cabezas lat: 14.0351, temp: 30, humidity: 70, cloudiness: 40, wind speed: 5.14
# 1: safwah lat: 14.0351, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: sokoni lat: -6.4333, temp: 27, humidity: 83, cloudiness: 20, wind speed: 5.14
# 1: buzdyak lat: 54.5833, temp: 2, humidity: 98, cloudiness: 100, wind speed: 4.74
# 1: barra do garcas lat: -15.89, temp: 32, humidity: 31, cloudiness: 0, wind speed: 1.54
# 1: ekibastuz lat: 51.6667, temp: 1, humidity: 49, cloudiness: 29, wind speed: 3.07
# 1: opuwo lat: -18.0607, temp: 25, humidity: 27, cloudiness: 64, wind speed: 3.14
# 1: garmsar lat: 35.2182, temp: 28, humidity: 19, cloudiness: 75, wind speed: 1.43
# 1: malwan lat: 35.2182, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: garissa lat: -0.4536, temp: 29, humidity: 57, cloudiness: 97, wind speed: 8.52
# 1: taybad lat: 34.74, temp: 18, humidity: 10, cloudiness: 8, wind speed: 6.83
# 1: kutum lat: 14.2, temp: 28, humidity: 14, cloudiness: 17, wind speed: 2.93
# 1: puri lat: 19.8, temp: 27, humidity: 94, cloudiness: 40, wind speed: 5.71
# 1: grand gaube lat: -20.0064, temp: 26, humidity: 82, cloudiness: 100, wind speed: 0.89
# 1: mosquera lat: 4.7059, temp: 20, humidity: 56, cloudiness: 40, wind speed: 5.14
# 1: umm kaddadah lat: 13.6017, temp: 32, humidity: 14, cloudiness: 39, wind speed: 4.94
# 1: mantua lat: 45.1667, temp: 16, humidity: 62, cloudiness: 12, wind speed: 0.89
# 1: bela lat: 25.9333, temp: 28, humidity: 23, cloudiness: 10, wind speed: 3.52
# 1: ambodifototra lat: 25.9333, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: clyde river lat: 70.4692, temp: -7, humidity: 68, cloudiness: 75, wind speed: 3.6
# 1: amherst lat: 41.3978, temp: 7, humidity: 42, cloudiness: 90, wind speed: 5.66
# 1: kyrksaeterora lat: 63.2906, temp: 3, humidity: 75, cloudiness: 40, wind speed: 10.29
# 1: uyovu lat: -3.2833, temp: 19, humidity: 91, cloudiness: 90, wind speed: 1.2
# 1: puerto carreno lat: 6.189, temp: 37, humidity: 31, cloudiness: 13, wind speed: 2.3
# 1: iralaya lat: 15, temp: 29, humidity: 59, cloudiness: 38, wind speed: 5.26
# 1: ponta do sol lat: 32.6667, temp: 17, humidity: 89, cloudiness: 100, wind speed: 0.45
# 1: boo lat: 59.3333, temp: 1, humidity: 87, cloudiness: 75, wind speed: 5.14
# 1: tukrah lat: 32.5341, temp: 22, humidity: 35, cloudiness: 85, wind speed: 3.26
# 1: escanaba lat: 45.7453, temp: 7, humidity: 39, cloudiness: 1, wind speed: 7.2
# 1: koupela lat: 12.1794, temp: 38, humidity: 20, cloudiness: 77, wind speed: 0.73
# 1: salekhard lat: 66.53, temp: 2, humidity: 90, cloudiness: 100, wind speed: 4.4
# 1: qobustan lat: 40.0824, temp: 13, humidity: 76, cloudiness: 40, wind speed: 8.23
# 1: porbandar lat: 21.6422, temp: 27, humidity: 78, cloudiness: 14, wind speed: 5.1
# 1: guiratinga lat: -16.3494, temp: 31, humidity: 31, cloudiness: 0, wind speed: 0.82
# 1: jablah lat: 35.3614, temp: 17, humidity: 72, cloudiness: 0, wind speed: 2.06
# 1: belyy yar lat: 53.6039, temp: -1, humidity: 51, cloudiness: 0, wind speed: 4
# 1: najran lat: 17.4924, temp: 27, humidity: 14, cloudiness: 0, wind speed: 2.06
# 1: liverpool lat: 53.4106, temp: 16, humidity: 29, cloudiness: 0, wind speed: 2.06
# 1: sioux lookout lat: 50.1001, temp: 14, humidity: 33, cloudiness: 40, wind speed: 4.63
# 1: tutoia lat: -2.7619, temp: 30, humidity: 70, cloudiness: 75, wind speed: 4.12
# 1: batticaloa lat: 7.7102, temp: 28, humidity: 79, cloudiness: 10, wind speed: 2.71
# 1: itamaraca lat: -7.7478, temp: 28, humidity: 65, cloudiness: 20, wind speed: 4.12
# 1: karpathos lat: 35.507, temp: 16, humidity: 77, cloudiness: 2, wind speed: 9.26
# 1: fez lat: 34.0372, temp: 20, humidity: 56, cloudiness: 75, wind speed: 1.54
# 1: ormara lat: 25.2088, temp: 28, humidity: 71, cloudiness: 0, wind speed: 6.99
# 1: tsihombe lat: 25.2088, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: teplyk lat: 48.6657, temp: 11, humidity: 75, cloudiness: 51, wind speed: 4.05
# 1: kaniama lat: -7.5667, temp: 21, humidity: 91, cloudiness: 100, wind speed: 1.62
# 1: general roca lat: -39.0333, temp: 18, humidity: 48, cloudiness: 0, wind speed: 2.06
# 1: canaries lat: 28, temp: 21, humidity: 64, cloudiness: 20, wind speed: 8.23
# 1: filla lat: 38.4333, temp: 15, humidity: 39, cloudiness: 20, wind speed: 2.57
# 1: qaqortoq lat: 60.7167, temp: 12, humidity: 28, cloudiness: 40, wind speed: 7.2
# 1: tulu bolo lat: 8.6667, temp: 19, humidity: 54, cloudiness: 99, wind speed: 0.88
# 1: visby lat: 57.6409, temp: 2, humidity: 93, cloudiness: 75, wind speed: 11.32
# 1: nienburg lat: 52.6333, temp: 9, humidity: 49, cloudiness: 48, wind speed: 6.69
# 1: jacareacanga lat: -6.2222, temp: 31, humidity: 74, cloudiness: 20, wind speed: 1.03
# 1: dondo lat: -19.6094, temp: 24, humidity: 69, cloudiness: 20, wind speed: 2.3
# 1: meulaboh lat: 4.1363, temp: 25, humidity: 88, cloudiness: 96, wind speed: 1.26
# 1: shahreza lat: 32.0339, temp: 20, humidity: 38, cloudiness: 83, wind speed: 2.11
# 1: syamzha lat: 60.0158, temp: 4, humidity: 94, cloudiness: 86, wind speed: 2.64
# 1: cowansville lat: 45.2001, temp: -2, humidity: 93, cloudiness: 100, wind speed: 6.69
# 1: nicoya lat: 10.1483, temp: 33, humidity: 38, cloudiness: 0, wind speed: 9.77
# 1: malinovskiy lat: 61.1953, temp: 9, humidity: 51, cloudiness: 100, wind speed: 4.2
# 1: laguna lat: 38.421, temp: 17, humidity: 59, cloudiness: 1, wind speed: 5.66
# 1: strezhevoy lat: 60.7333, temp: 0, humidity: 55, cloudiness: 0, wind speed: 3
# 1: road town lat: 18.4167, temp: 29, humidity: 65, cloudiness: 40, wind speed: 5.14
# 1: kalabo lat: -14.97, temp: 22, humidity: 44, cloudiness: 16, wind speed: 2.41
# 1: chipinge lat: -20.1883, temp: 16, humidity: 79, cloudiness: 71, wind speed: 2.2
# 1: emborion lat: 40.4833, temp: 11, humidity: 76, cloudiness: 100, wind speed: 0.51
# 1: kosh-agach lat: 50, temp: -6, humidity: 59, cloudiness: 85, wind speed: 1.88
# 1: port blair lat: 11.6667, temp: 27, humidity: 75, cloudiness: 24, wind speed: 2.27
# 1: montecristo lat: 8.2971, temp: 32, humidity: 61, cloudiness: 40, wind speed: 0.66
# 1: carballo lat: 43.213, temp: 16, humidity: 85, cloudiness: 97, wind speed: 1.34
# 1: kavaratti lat: 10.5669, temp: 29, humidity: 68, cloudiness: 98, wind speed: 4.06
# 1: carauari lat: -4.8828, temp: 30, humidity: 72, cloudiness: 31, wind speed: 0.81
# 1: sambava lat: -14.2667, temp: 25, humidity: 88, cloudiness: 91, wind speed: 5.09
# 1: aquiraz lat: -3.9014, temp: 30, humidity: 70, cloudiness: 75, wind speed: 4.63
# 1: nassau lat: 40.7507, temp: 8, humidity: 31, cloudiness: 75, wind speed: 7.2
# 1: nedjo lat: 9.5046, temp: 18, humidity: 72, cloudiness: 100, wind speed: 1.47
# 1: ulundi lat: -28.3352, temp: 17, humidity: 94, cloudiness: 53, wind speed: 1.04
# 1: san javier lat: 37.8063, temp: 16, humidity: 94, cloudiness: 40, wind speed: 3.09
# 1: nantucket lat: 41.2835, temp: 6, humidity: 45, cloudiness: 90, wind speed: 11.32
# 1: thano bula khan lat: 41.2835, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: itacarambi lat: -15.1022, temp: 30, humidity: 44, cloudiness: 51, wind speed: 0.95
# 1: kuryk lat: 43.2, temp: 15, humidity: 66, cloudiness: 81, wind speed: 2.52
# 1: cacu lat: -18.5567, temp: 32, humidity: 21, cloudiness: 0, wind speed: 1.93
# 1: argentan lat: 48.75, temp: 12, humidity: 66, cloudiness: 0, wind speed: 5.14
# 1: conceicao do araguaia lat: -8.2578, temp: 31, humidity: 62, cloudiness: 40, wind speed: 1.54
# 1: garachine lat: 8.0647, temp: 29, humidity: 65, cloudiness: 64, wind speed: 2.26
# 1: zharkent lat: 44.1628, temp: 6, humidity: 34, cloudiness: 17, wind speed: 7.01
# 1: cayenne lat: 4.9333, temp: 28, humidity: 70, cloudiness: 75, wind speed: 5.14
# 1: rocha lat: -34.4833, temp: 23, humidity: 59, cloudiness: 12, wind speed: 4.78
# 1: henties bay lat: -22.116, temp: 21, humidity: 78, cloudiness: 41, wind speed: 1.79
# 1: karagach lat: 43.8053, temp: 12, humidity: 76, cloudiness: 90, wind speed: 2
# 1: luderitz lat: -26.6481, temp: 18, humidity: 82, cloudiness: 0, wind speed: 4.13
# 1: springbok lat: -29.6643, temp: 20, humidity: 42, cloudiness: 6, wind speed: 1.4
# 1: lerwick lat: 60.1545, temp: 7, humidity: 70, cloudiness: 75, wind speed: 3.09
# 1: clonakilty lat: 51.6231, temp: 10, humidity: 71, cloudiness: 0, wind speed: 8.23
# 1: gerede lat: 40.8008, temp: 4, humidity: 83, cloudiness: 9, wind speed: 0.63
# 1: port-gentil lat: -0.7193, temp: 26, humidity: 81, cloudiness: 98, wind speed: 6.21
# 1: malinovoye ozero lat: 51.6753, temp: 0, humidity: 53, cloudiness: 21, wind speed: 4.14
# 1: porto walter lat: -8.2686, temp: 30, humidity: 62, cloudiness: 11, wind speed: 1.73
# 1: cacule lat: -14.5033, temp: 26, humidity: 74, cloudiness: 74, wind speed: 1.5
# 1: suluq lat: 31.6682, temp: 26, humidity: 18, cloudiness: 93, wind speed: 4.06
# 1: barra patuca lat: 15.8, temp: 29, humidity: 62, cloudiness: 18, wind speed: 5.55
# 1: acarau lat: -2.8856, temp: 29, humidity: 70, cloudiness: 31, wind speed: 4.4
# 1: talah lat: -2.8856, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: chapais lat: 49.7834, temp: -3, humidity: 59, cloudiness: 90, wind speed: 6.69
# 1: kampene lat: -3.6, temp: 22, humidity: 93, cloudiness: 52, wind speed: 0.89
# 1: brae lat: 60.3964, temp: 7, humidity: 70, cloudiness: 75, wind speed: 3.09
# 1: sidi ali lat: 36.0998, temp: 16, humidity: 71, cloudiness: 100, wind speed: 1.91
# 1: kismayo lat: -0.3582, temp: 28, humidity: 77, cloudiness: 100, wind speed: 6.9
# 1: saldanha lat: -33.0117, temp: 16, humidity: 77, cloudiness: 5, wind speed: 3.6
# 1: allingabro lat: 56.465, temp: 8, humidity: 43, cloudiness: 20, wind speed: 4.63
# 1: ilinskiy lat: 55.619, temp: 9, humidity: 87, cloudiness: 58, wind speed: 2
# 1: porsa lat: 26.67, temp: 28, humidity: 24, cloudiness: 0, wind speed: 4.2
# 1: diffa lat: 13.3154, temp: 34, humidity: 10, cloudiness: 25, wind speed: 3.33
# 1: ayorou lat: 14.7308, temp: 37, humidity: 7, cloudiness: 46, wind speed: 2.12
# 1: conde lat: -7.2597, temp: 29, humidity: 79, cloudiness: 40, wind speed: 4.63
# 1: marabba lat: 12.35, temp: 35, humidity: 23, cloudiness: 96, wind speed: 3.44
# 1: gobabis lat: -22.45, temp: 19, humidity: 32, cloudiness: 53, wind speed: 4.3
# 1: krasnoarmeysk lat: 51.0239, temp: 11, humidity: 65, cloudiness: 65, wind speed: 0.43
# 1: maun lat: -19.9833, temp: 18, humidity: 59, cloudiness: 0, wind speed: 2.38
# 1: santa rosa lat: 14.3122, temp: 28, humidity: 78, cloudiness: 75, wind speed: 3.6
# 1: goderich lat: 43.7501, temp: 2, humidity: 64, cloudiness: 100, wind speed: 5.66
# 1: bargal lat: 43.7501, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: derzhavinsk lat: 51.1, temp: 7, humidity: 44, cloudiness: 93, wind speed: 6.68
# 1: salamiyah lat: 35.0113, temp: 16, humidity: 40, cloudiness: 1, wind speed: 2.65
# 1: gamba lat: -2.65, temp: 26, humidity: 79, cloudiness: 99, wind speed: 1.41
# 1: camacha lat: 33.0833, temp: 22, humidity: 73, cloudiness: 20, wind speed: 7.2
# 1: staroye drozhzhanoye lat: 54.7266, temp: 8, humidity: 75, cloudiness: 27, wind speed: 1.39
# 1: santa vitoria do palmar lat: -33.5189, temp: 23, humidity: 56, cloudiness: 12, wind speed: 6.18
# 1: talnakh lat: 69.4865, temp: -1, humidity: 95, cloudiness: 100, wind speed: 4.21
# 1: kitale lat: 1.0157, temp: 15, humidity: 92, cloudiness: 100, wind speed: 0.52
# 1: toamasina lat: -18.1667, temp: 23, humidity: 89, cloudiness: 100, wind speed: 1.12
# 1: roxana lat: 10.2753, temp: 24, humidity: 68, cloudiness: 20, wind speed: 8.75
# 1: mlimba lat: -8.8, temp: 22, humidity: 95, cloudiness: 34, wind speed: 1.54
# 1: tocopilla lat: -22.092, temp: 21, humidity: 68, cloudiness: 9, wind speed: 3.81
# 1: deder lat: 9.3167, temp: 15, humidity: 72, cloudiness: 96, wind speed: 1.56
# 1: el badari lat: 9.3167, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: herbertpur lat: 30.45, temp: 19, humidity: 62, cloudiness: 39, wind speed: 4.2
# 1: igarka lat: 67.4667, temp: 0, humidity: 97, cloudiness: 100, wind speed: 5.42
# 1: manaure lat: 11.7751, temp: 31, humidity: 49, cloudiness: 16, wind speed: 7.21
# 1: angoche lat: -16.2325, temp: 26, humidity: 76, cloudiness: 76, wind speed: 4.3
# 1: naryan-mar lat: 67.6713, temp: 3, humidity: 97, cloudiness: 100, wind speed: 7.22
# 1: warqla lat: 67.6713, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: kluczbork lat: 50.9728, temp: 7, humidity: 53, cloudiness: 7, wind speed: 3.58
# 1: raga lat: 8.4596, temp: 31, humidity: 33, cloudiness: 91, wind speed: 2.88
# 1: saint anthony lat: 45.0205, temp: 16, humidity: 22, cloudiness: 1, wind speed: 4.12
# 1: progreso lat: 21.2833, temp: 33, humidity: 55, cloudiness: 75, wind speed: 4.12
# 1: dudinka lat: 69.4058, temp: 1, humidity: 85, cloudiness: 100, wind speed: 7.05
# 1: belmonte lat: -15.8631, temp: 27, humidity: 69, cloudiness: 20, wind speed: 3.09
# 1: walvis bay lat: -22.9575, temp: 23, humidity: 47, cloudiness: 22, wind speed: 3.09
# 1: bollnas lat: 61.3482, temp: 6, humidity: 40, cloudiness: 84, wind speed: 1.34
# 1: lambarene lat: -0.7001, temp: 25, humidity: 92, cloudiness: 100, wind speed: 3.65
# 1: cabedelo lat: -6.9811, temp: 29, humidity: 79, cloudiness: 40, wind speed: 4.63
# 1: saint-joseph lat: -21.3667, temp: 23, humidity: 78, cloudiness: 75, wind speed: 9.26
# 1: iracoubo lat: 5.4802, temp: 26, humidity: 87, cloudiness: 65, wind speed: 5.86
# 1: little current lat: 45.9793, temp: 4, humidity: 56, cloudiness: 70, wind speed: 8.23
# 1: inongo lat: -1.95, temp: 27, humidity: 69, cloudiness: 55, wind speed: 1.29
# 1: berlevag lat: 70.8578, temp: 2, humidity: 75, cloudiness: 40, wind speed: 7.2
# 1: miragoane lat: 18.4423, temp: 28, humidity: 59, cloudiness: 5, wind speed: 2.54
# 1: suez lat: 29.9737, temp: 18, humidity: 50, cloudiness: 1, wind speed: 6.16
# 1: ndele lat: 8.4109, temp: 31, humidity: 33, cloudiness: 82, wind speed: 1.69
# 1: margate lat: 51.3813, temp: 8, humidity: 60, cloudiness: 9, wind speed: 1.79
# 1: kudahuvadhoo lat: 2.6708, temp: 28, humidity: 71, cloudiness: 32, wind speed: 5.3
# 1: dwarka lat: 22.2394, temp: 27, humidity: 80, cloudiness: 0, wind speed: 5.68
# 1: macae lat: -22.3708, temp: 26, humidity: 65, cloudiness: 75, wind speed: 5.66
# 1: dedovichi lat: 57.5517, temp: 7, humidity: 90, cloudiness: 100, wind speed: 3.04
# 1: the valley lat: 18.217, temp: 29, humidity: 61, cloudiness: 20, wind speed: 6.69
# 1: semey lat: 50.4111, temp: 0, humidity: 53, cloudiness: 60, wind speed: 5.38
# 1: wattegama lat: 6.7989, temp: 25, humidity: 90, cloudiness: 27, wind speed: 0.86
# 1: kolosovka lat: 56.4678, temp: 0, humidity: 64, cloudiness: 14, wind speed: 3.52
# 1: cansancao lat: -10.6672, temp: 32, humidity: 44, cloudiness: 36, wind speed: 1.49
# 1: manjacaze lat: -24.7117, temp: 20, humidity: 77, cloudiness: 36, wind speed: 3.36
# 1: hamina lat: 60.5697, temp: 7, humidity: 49, cloudiness: 0, wind speed: 3.09
# 1: karpogory lat: 64.0019, temp: 4, humidity: 91, cloudiness: 100, wind speed: 4.17
# 1: duz lat: 64.0019, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: abay lat: 49.6311, temp: -7, humidity: 73, cloudiness: 0, wind speed: 2
# 1: marsa matruh lat: 31.3525, temp: 17, humidity: 67, cloudiness: 40, wind speed: 4.63
# 1: bereda lat: 43.2686, temp: 16, humidity: 74, cloudiness: 76, wind speed: 4.92
# 1: marystown lat: 47.1666, temp: 6, humidity: 95, cloudiness: 100, wind speed: 11.67
# 1: velyka bilozerka lat: 47.2776, temp: 10, humidity: 81, cloudiness: 83, wind speed: 4.01
# 1: zarate lat: -34.0981, temp: 25, humidity: 64, cloudiness: 100, wind speed: 1.79
# 1: potamia lat: 40.7163, temp: 15, humidity: 82, cloudiness: 20, wind speed: 3.09
# 1: vytegra lat: 61.0064, temp: 3, humidity: 92, cloudiness: 85, wind speed: 2.62
# 1: kanadey lat: 53.1679, temp: 9, humidity: 82, cloudiness: 35, wind speed: 2.26
# 1: despotovac lat: 44.0925, temp: 12, humidity: 36, cloudiness: 100, wind speed: 1.84
# 1: olafsvik lat: 64.8945, temp: 6, humidity: 93, cloudiness: 100, wind speed: 8.47
# 1: floro lat: 61.5996, temp: 5, humidity: 65, cloudiness: 75, wind speed: 4.63
# 1: odweyne lat: 9.4092, temp: 27, humidity: 46, cloudiness: 81, wind speed: 4.91
# 1: cap malheureux lat: -19.9842, temp: 26, humidity: 82, cloudiness: 100, wind speed: 0.89
# 1: sao paulo de olivenca lat: -3.3783, temp: 28, humidity: 76, cloudiness: 96, wind speed: 0.72
# 1: joensuu lat: 62.6012, temp: 5, humidity: 87, cloudiness: 0, wind speed: 4.12
# 1: cervo lat: 43.6702, temp: 17, humidity: 80, cloudiness: 72, wind speed: 2.46
# 1: port hawkesbury lat: 45.6169, temp: 6, humidity: 87, cloudiness: 90, wind speed: 7.72
# 1: port-cartier lat: 50.0334, temp: 4, humidity: 100, cloudiness: 90, wind speed: 3.09
# 1: mizdah lat: 31.4451, temp: 26, humidity: 24, cloudiness: 19, wind speed: 8.24
# 1: eyl lat: 7.9803, temp: 29, humidity: 72, cloudiness: 68, wind speed: 3.95
# 1: alfatar lat: 43.95, temp: 12, humidity: 66, cloudiness: 81, wind speed: 2.68
# 1: jatai lat: -17.8814, temp: 29, humidity: 25, cloudiness: 0, wind speed: 1.38
# 1: otavi lat: -19.65, temp: 20, humidity: 34, cloudiness: 33, wind speed: 3.7
# 1: dhilwan lat: 31.5169, temp: 18, humidity: 63, cloudiness: 40, wind speed: 6.17
# 1: inyonga lat: -6.7167, temp: 19, humidity: 83, cloudiness: 83, wind speed: 2.01
# 1: pangody lat: 65.85, temp: 0, humidity: 90, cloudiness: 100, wind speed: 7.59
# 1: nuuk lat: 64.1835, temp: 3, humidity: 70, cloudiness: 1, wind speed: 1.03
# 1: itacoatiara lat: -3.1431, temp: 30, humidity: 68, cloudiness: 75, wind speed: 1.41
# 1: micheweni lat: -4.9667, temp: 27, humidity: 84, cloudiness: 99, wind speed: 5.97
# 1: samana lat: 19.2056, temp: 31, humidity: 62, cloudiness: 40, wind speed: 7.72
# 1: faya lat: 18.3851, temp: 20, humidity: 48, cloudiness: 0, wind speed: 3.6
# 1: oum hadjer lat: 13.2954, temp: 32, humidity: 29, cloudiness: 71, wind speed: 8.84
# 1: sovetskaya lat: 44.7769, temp: 10, humidity: 95, cloudiness: 99, wind speed: 1.73
# 1: mikhaylovskoye lat: 51.8239, temp: -1, humidity: 54, cloudiness: 18, wind speed: 4.25
# 1: tiznit lat: 29.5833, temp: 18, humidity: 56, cloudiness: 26, wind speed: 3.38
# 1: longlac lat: 29.5833, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: villacidro lat: 39.4578, temp: 16, humidity: 88, cloudiness: 40, wind speed: 1.03
# 1: grave lat: 51.759, temp: 10, humidity: 50, cloudiness: 90, wind speed: 4.12
# 1: alvand lat: 36.3187, temp: 15, humidity: 60, cloudiness: 100, wind speed: 2.15
# 1: carnarvon lat: -24.8667, temp: 22, humidity: 83, cloudiness: 40, wind speed: 3.09
# 1: saumur lat: 47.3333, temp: 18, humidity: 48, cloudiness: 0, wind speed: 5.14
# 1: agadez lat: 19.75, temp: 35, humidity: 6, cloudiness: 37, wind speed: 5.48
# 1: wahran lat: 19.75, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: skalistyy lat: 19.75, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: sao joao da barra lat: -21.6403, temp: 27, humidity: 57, cloudiness: 40, wind speed: 5.14
# 1: eskasem lat: -21.6403, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: kathmandu lat: 27.7167, temp: 16, humidity: 59, cloudiness: 20, wind speed: 2.06
# 1: zarechnyy lat: 53.2036, temp: 11, humidity: 36, cloudiness: 75, wind speed: 0.48
# 1: barawe lat: 53.2036, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: dejen lat: 10.1667, temp: 19, humidity: 40, cloudiness: 100, wind speed: 1.97
# 1: shakhtinsk lat: 49.71, temp: -7, humidity: 73, cloudiness: 0, wind speed: 2
# 1: greenfield lat: 42.9614, temp: 11, humidity: 35, cloudiness: 20, wind speed: 4.63
# 1: dinsor lat: 42.9614, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: pereslavl-zalesskiy lat: 56.7393, temp: 7, humidity: 89, cloudiness: 56, wind speed: 3.36
# 1: isla mujeres lat: 21.2311, temp: 29, humidity: 62, cloudiness: 40, wind speed: 7.72
# 1: omboue lat: -1.5746, temp: 24, humidity: 95, cloudiness: 100, wind speed: 0.91
# 1: kemin lat: 42.7846, temp: 1, humidity: 75, cloudiness: 25, wind speed: 1.86
# 1: marawi lat: 7.9986, temp: 25, humidity: 78, cloudiness: 24, wind speed: 2.24
# 1: sarmanovo lat: 55.2553, temp: 6, humidity: 70, cloudiness: 0, wind speed: 4
# 1: imbituba lat: -28.24, temp: 24, humidity: 57, cloudiness: 40, wind speed: 3.6
# 1: aracruz lat: -19.8203, temp: 27, humidity: 73, cloudiness: 20, wind speed: 5.14
# 1: plettenberg bay lat: -34.0527, temp: 19, humidity: 87, cloudiness: 0, wind speed: 4.84
# 1: sinnar lat: 13.5691, temp: 37, humidity: 18, cloudiness: 72, wind speed: 3.13
# 1: nybro lat: 56.7446, temp: 4, humidity: 70, cloudiness: 75, wind speed: 6.69
# 1: klaksvik lat: 62.2266, temp: 7, humidity: 70, cloudiness: 75, wind speed: 2.57
# 1: somerset west lat: -34.084, temp: 17, humidity: 88, cloudiness: 0, wind speed: 3.6
# 1: kankakee lat: 41.15, temp: 11, humidity: 40, cloudiness: 75, wind speed: 7.2
# 1: palora lat: -1.7, temp: 24, humidity: 69, cloudiness: 75, wind speed: 1.03
# 1: marzuq lat: 14.4, temp: 23, humidity: 47, cloudiness: 16, wind speed: 2.93
# 1: awjilah lat: 29.1081, temp: 27, humidity: 13, cloudiness: 96, wind speed: 5.59
# 1: goundam lat: 16.4145, temp: 39, humidity: 9, cloudiness: 39, wind speed: 3.1
# 1: mbandaka lat: 0.0487, temp: 26, humidity: 69, cloudiness: 66, wind speed: 2.02
# 1: mari-turek lat: 56.7895, temp: 5, humidity: 91, cloudiness: 77, wind speed: 4.31
# 1: puerto ayacucho lat: 5.6639, temp: 35, humidity: 38, cloudiness: 12, wind speed: 0.88
# 1: huarmey lat: -10.0681, temp: 23, humidity: 73, cloudiness: 41, wind speed: 4.92
# 1: iberia lat: 29.9502, temp: 20, humidity: 45, cloudiness: 1, wind speed: 3.6
# 1: kachikau lat: 29.9502, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: ocho rios lat: 18.4025, temp: 29, humidity: 80, cloudiness: 0, wind speed: 5.81
# 1: coracao de jesus lat: -16.6853, temp: 30, humidity: 37, cloudiness: 40, wind speed: 2.57
# 1: grayvoron lat: 50.4767, temp: 9, humidity: 81, cloudiness: 0, wind speed: 3
# 1: aguada de pasajeros lat: 22.385, temp: 32, humidity: 51, cloudiness: 40, wind speed: 5.66
# 1: temir lat: 49.1414, temp: 9, humidity: 60, cloudiness: 100, wind speed: 7.62
# 1: yako lat: 12.9667, temp: 32, humidity: 34, cloudiness: 96, wind speed: 6.77
# 1: salmas lat: 38.1973, temp: 17, humidity: 45, cloudiness: 75, wind speed: 3.09
# 1: senneterre lat: 48.3835, temp: 2, humidity: 41, cloudiness: 40, wind speed: 5.14
# 1: rondonopolis lat: -16.4708, temp: 36, humidity: 22, cloudiness: 10, wind speed: 0.22
# 1: havre-saint-pierre lat: 50.2334, temp: 6, humidity: 100, cloudiness: 90, wind speed: 11.32
# 1: harda lat: 22.3333, temp: 31, humidity: 13, cloudiness: 80, wind speed: 2.09
# 1: dakar lat: 14.6937, temp: 22, humidity: 83, cloudiness: 0, wind speed: 4.12
# 1: boa vista lat: 2.8197, temp: 32, humidity: 48, cloudiness: 75, wind speed: 7.72
# 1: bud lat: 39.447, temp: 9, humidity: 43, cloudiness: 75, wind speed: 5.14
# 1: tornio lat: 65.8481, temp: 3, humidity: 87, cloudiness: 0, wind speed: 4.63
# 1: porto-vecchio lat: 41.591, temp: 13, humidity: 76, cloudiness: 0, wind speed: 3.6
# 1: manyana lat: -23.4, temp: 19, humidity: 28, cloudiness: 100, wind speed: 2.04
# 1: bonga lat: 7.2833, temp: 16, humidity: 98, cloudiness: 95, wind speed: 0.91
# 1: oistins lat: 13.0667, temp: 29, humidity: 58, cloudiness: 40, wind speed: 9.26
# 1: santiago del estero lat: -27.7951, temp: 20, humidity: 90, cloudiness: 100, wind speed: 3.33
# 1: simplicio mendes lat: -7.8539, temp: 30, humidity: 59, cloudiness: 57, wind speed: 0.55
# 1: nouakchott lat: 18.0858, temp: 23, humidity: 64, cloudiness: 55, wind speed: 10.8
# 1: dolbeau lat: 18.0858, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: itarema lat: -2.9248, temp: 29, humidity: 68, cloudiness: 27, wind speed: 4.35
# 1: matara lat: 5.9485, temp: 26, humidity: 88, cloudiness: 50, wind speed: 3.46
# 1: axim lat: 4.8699, temp: 29, humidity: 76, cloudiness: 100, wind speed: 3.78
# 1: ozgon lat: 4.8699, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: kegayli lat: 4.8699, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: akureyri lat: 65.6835, temp: 5, humidity: 81, cloudiness: 0, wind speed: 4.12
# 1: carahue lat: -38.7, temp: 16, humidity: 67, cloudiness: 0, wind speed: 2.57
# 1: charlestown lat: -32.95, temp: 10, humidity: 61, cloudiness: 0, wind speed: 1.34
# 1: novopokrovka lat: 49.8425, temp: 12, humidity: 62, cloudiness: 0, wind speed: 2
# 1: warri lat: 5.5167, temp: 28, humidity: 78, cloudiness: 100, wind speed: 3.02
# 1: kinango lat: -4.1372, temp: 25, humidity: 84, cloudiness: 95, wind speed: 3.38
# 1: aqtobe lat: 50.2797, temp: 10, humidity: 50, cloudiness: 0, wind speed: 4
# 1: puerto el triunfo lat: 13.2833, temp: 34, humidity: 38, cloudiness: 0, wind speed: 1.54
# 1: chimbote lat: -9.0853, temp: 23, humidity: 72, cloudiness: 49, wind speed: 4.57
# 1: pizarro lat: 4.9533, temp: 28, humidity: 73, cloudiness: 26, wind speed: 3.63
# 1: peniche lat: 39.3558, temp: 16, humidity: 79, cloudiness: 86, wind speed: 3.58
# 1: durazno lat: -33.4131, temp: 26, humidity: 57, cloudiness: 40, wind speed: 6.17
# 1: chudniv lat: 50.052, temp: 9, humidity: 91, cloudiness: 96, wind speed: 3.32
# 1: lohr lat: 49.9936, temp: 10, humidity: 46, cloudiness: 69, wind speed: 1.68
# 1: sawakin lat: 19.1059, temp: 28, humidity: 73, cloudiness: 1, wind speed: 2.74
# 1: rio gallegos lat: -51.6226, temp: 12, humidity: 47, cloudiness: 75, wind speed: 1.03
# 1: maniitsoq lat: 65.4167, temp: 2, humidity: 65, cloudiness: 12, wind speed: 2.26
# 1: fernandina beach lat: 30.6697, temp: 17, humidity: 48, cloudiness: 40, wind speed: 6.17
# 1: marivan lat: 35.5219, temp: 18, humidity: 44, cloudiness: 91, wind speed: 1.35
# 1: padang lat: -0.9492, temp: 24, humidity: 94, cloudiness: 75, wind speed: 1.54
# 1: channel-port aux basques lat: 47.5702, temp: 5, humidity: 97, cloudiness: 100, wind speed: 13.6
# 1: beinamar lat: 8.6698, temp: 31, humidity: 39, cloudiness: 78, wind speed: 3.23
# 1: toliary lat: 8.6698, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: cabrobo lat: -8.5142, temp: 32, humidity: 45, cloudiness: 64, wind speed: 0.74
# 1: hornepayne lat: 49.2138, temp: 6, humidity: 51, cloudiness: 95, wind speed: 4.4
# 1: mecca lat: 21.4267, temp: 31, humidity: 33, cloudiness: 93, wind speed: 2.04
# 1: biltine lat: 14.5333, temp: 35, humidity: 10, cloudiness: 15, wind speed: 4.5
# 1: ciechanow lat: 52.8814, temp: 5, humidity: 93, cloudiness: 75, wind speed: 3.6
# 1: iguape lat: -24.7081, temp: 23, humidity: 63, cloudiness: 9, wind speed: 4.26
# 1: aracati lat: -4.5617, temp: 30, humidity: 61, cloudiness: 29, wind speed: 4.96
# 1: riohacha lat: 11.5444, temp: 32, humidity: 54, cloudiness: 44, wind speed: 5.76
# 1: salto lat: -31.3833, temp: 27, humidity: 65, cloudiness: 0, wind speed: 3.09
# 1: szamosszeg lat: 48.0456, temp: 9, humidity: 87, cloudiness: 75, wind speed: 1.54
# 1: stantsiya gorchakovo lat: 48.0456, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: richards bay lat: -28.783, temp: 20, humidity: 87, cloudiness: 44, wind speed: 0.92
# 1: sorland lat: 67.667, temp: 3, humidity: 65, cloudiness: 40, wind speed: 6.17
# 1: iquique lat: -20.2208, temp: 22, humidity: 56, cloudiness: 0, wind speed: 5.66
# 1: talcher lat: 20.95, temp: 28, humidity: 59, cloudiness: 35, wind speed: 3.03
# 1: vuktyl lat: 63.8567, temp: 4, humidity: 97, cloudiness: 100, wind speed: 5.3
# 1: namikupa lat: -10.8333, temp: 21, humidity: 97, cloudiness: 21, wind speed: 1.06
# 1: andenes lat: 69.3143, temp: 2, humidity: 64, cloudiness: 20, wind speed: 7.72
# 1: pavda lat: 69.3143, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: olinda lat: -8.0089, temp: 28, humidity: 65, cloudiness: 20, wind speed: 4.12
# 1: tartki lat: -8.0089, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: petrokamenskoye lat: 57.716, temp: 6, humidity: 75, cloudiness: 100, wind speed: 2.06
# 1: hambantota lat: 6.1241, temp: 27, humidity: 82, cloudiness: 41, wind speed: 5.69
# 1: abonnema lat: 4.7084, temp: 28, humidity: 77, cloudiness: 100, wind speed: 3.8
# 1: karkaralinsk lat: 4.7084, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: talcahuano lat: -36.7167, temp: 16, humidity: 67, cloudiness: 0, wind speed: 5.66
# 1: pionerskiy lat: 54.9508, temp: 3, humidity: 87, cloudiness: 75, wind speed: 6
# 1: bokspits lat: 54.9508, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: arenapolis lat: -14.4503, temp: 34, humidity: 34, cloudiness: 20, wind speed: 1.09
# 1: mullaitivu lat: -14.4503, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: la union lat: -5.4, temp: 31, humidity: 42, cloudiness: 20, wind speed: 5.71
# 1: oshnaviyeh lat: 37.0397, temp: 19, humidity: 39, cloudiness: 75, wind speed: 4.12
# 1: miraflores lat: 19.2167, temp: 24, humidity: 16, cloudiness: 40, wind speed: 2.57
# 1: dalkola lat: 25.85, temp: 26, humidity: 39, cloudiness: 28, wind speed: 2.79
# 1: pudozh lat: 61.8099, temp: 3, humidity: 95, cloudiness: 100, wind speed: 1.73
# 1: urengoy lat: 65.9667, temp: -2, humidity: 93, cloudiness: 94, wind speed: 6.57
# 1: swellendam lat: -34.0226, temp: 15, humidity: 94, cloudiness: 11, wind speed: 2.57
# 1: black river lat: 18.0264, temp: 29, humidity: 70, cloudiness: 20, wind speed: 7.2
# 1: bocana de paiwas lat: 12.7857, temp: 32, humidity: 33, cloudiness: 27, wind speed: 6.97
# 1: san rafael lat: -34.6177, temp: 19, humidity: 46, cloudiness: 99, wind speed: 2
# 1: merrill lat: 45.1805, temp: 11, humidity: 40, cloudiness: 1, wind speed: 4.63
# 1: luba lat: 3.4568, temp: 28, humidity: 79, cloudiness: 99, wind speed: 3.4
# 1: hobyo lat: 5.3505, temp: 29, humidity: 72, cloudiness: 69, wind speed: 6.66
# 1: longavi lat: -35.9667, temp: 20, humidity: 52, cloudiness: 81, wind speed: 2.98
# 1: roald lat: 62.5833, temp: 2, humidity: 87, cloudiness: 75, wind speed: 4.63
# 1: sept-iles lat: 50.2001, temp: 4, humidity: 100, cloudiness: 90, wind speed: 3.09
# 1: mocambique lat: 50.2001, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: porto nacional lat: -10.7081, temp: 26, humidity: 89, cloudiness: 40, wind speed: 2.57
# 1: rockingham lat: 42.9668, temp: 4, humidity: 31, cloudiness: 84, wind speed: 2.68
# 1: veraval lat: 20.9, temp: 27, humidity: 76, cloudiness: 62, wind speed: 4.83
# 1: rundu lat: -17.9333, temp: 20, humidity: 38, cloudiness: 0, wind speed: 2.39
# 1: kuche lat: -17.9333, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: watsa lat: 3.0372, temp: 19, humidity: 98, cloudiness: 92, wind speed: 1.02
# 1: sabha lat: 27.0377, temp: 30, humidity: 12, cloudiness: 67, wind speed: 5.39
# 1: armacao dos buzios lat: 27.0377, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: naron lat: 43.5167, temp: 14, humidity: 82, cloudiness: 20, wind speed: 4.12
# 1: gayeri lat: 12.6497, temp: 37, humidity: 22, cloudiness: 97, wind speed: 1.33
# 1: kintampo lat: 8.0563, temp: 30, humidity: 48, cloudiness: 93, wind speed: 2.77
# 1: fairborn lat: 39.8209, temp: 8, humidity: 43, cloudiness: 75, wind speed: 5.66
# 1: gairo lat: 39.8497, temp: 11, humidity: 94, cloudiness: 90, wind speed: 5.14
# 1: la sarre lat: 48.8002, temp: 4, humidity: 42, cloudiness: 94, wind speed: 5.3
# 1: tessalit lat: 20.1986, temp: 34, humidity: 5, cloudiness: 13, wind speed: 6.06
# 1: tucurui lat: -3.7661, temp: 28, humidity: 79, cloudiness: 48, wind speed: 1.73
# 1: gari lat: 59.4307, temp: 7, humidity: 67, cloudiness: 100, wind speed: 2.61
# 1: tsabong lat: -26.0217, temp: 22, humidity: 27, cloudiness: 0, wind speed: 2.23
# 1: buchanan lat: 5.8808, temp: 30, humidity: 74, cloudiness: 20, wind speed: 4.63
# ...
# 1: kharan lat: 28.5833, temp: 29, humidity: 10, cloudiness: 4, wind speed: 3.67
# 1: ntcheu lat: -14.8203, temp: 16, humidity: 93, cloudiness: 54, wind speed: 1.83
# 1: elizabeth city lat: 36.2946, temp: 13, humidity: 30, cloudiness: 1, wind speed: 4.63
# 1: pinega lat: 64.7001, temp: 3, humidity: 94, cloudiness: 98, wind speed: 3.45
# 1: mount pleasant lat: 32.7941, temp: 16, humidity: 25, cloudiness: 1, wind speed: 2.57
# 1: mangai lat: -4.05, temp: 26, humidity: 66, cloudiness: 45, wind speed: 1.02
# 1: natal lat: -5.795, temp: 30, humidity: 70, cloudiness: 75, wind speed: 5.66
# 1: juan lacaze lat: -34.4342, temp: 26, humidity: 54, cloudiness: 75, wind speed: 3.6
# 1: sosenskiy lat: 54.059, temp: 9, humidity: 87, cloudiness: 0, wind speed: 2
# 1: burica lat: 54.059, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: yeletskiy lat: 54.059, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: terre haute lat: 39.4667, temp: 11, humidity: 32, cloudiness: 40, wind speed: 5.66
# 1: bodden town lat: 19.2833, temp: 30, humidity: 70, cloudiness: 20, wind speed: 5.14
# 1: molepolole lat: -24.4066, temp: 16, humidity: 48, cloudiness: 0, wind speed: 1.54
# 1: newburgh lat: 41.5034, temp: 7, humidity: 36, cloudiness: 75, wind speed: 8.23
# 1: caconda lat: -13.7333, temp: 19, humidity: 53, cloudiness: 100, wind speed: 0.99
# 1: saint-augustin lat: 51.226, temp: 6, humidity: 76, cloudiness: 100, wind speed: 10.2
# 1: sisimiut lat: 66.9395, temp: 1, humidity: 67, cloudiness: 98, wind speed: 1.79
# 1: ikungi lat: -5.1333, temp: 18, humidity: 86, cloudiness: 100, wind speed: 3
# 1: sorata lat: -15.7667, temp: 13, humidity: 69, cloudiness: 17, wind speed: 3.95
# 1: kabinda lat: -6.1333, temp: 21, humidity: 87, cloudiness: 86, wind speed: 1.94
# 1: zlitan lat: 32.4674, temp: 24, humidity: 42, cloudiness: 13, wind speed: 7.57
# 1: los andes lat: -32.8337, temp: 21, humidity: 46, cloudiness: 0, wind speed: 4.12
# 1: visnes lat: 59.3556, temp: 6, humidity: 61, cloudiness: 20, wind speed: 10.29
# 1: bafoulabe lat: 13.8065, temp: 40, humidity: 10, cloudiness: 89, wind speed: 1.38
# 1: nynashamn lat: 58.9034, temp: 1, humidity: 90, cloudiness: 100, wind speed: 1.79
# 1: arak lat: 34.0917, temp: 21, humidity: 23, cloudiness: 87, wind speed: 0.81
# 1: harer lat: 9.3094, temp: 17, humidity: 77, cloudiness: 96, wind speed: 1.35
# 1: yumaguzino lat: 52.9041, temp: 3, humidity: 96, cloudiness: 100, wind speed: 3.49
# 1: kremze lat: 48.905, temp: 7, humidity: 53, cloudiness: 94, wind speed: 2.31
# 1: parambu lat: -6.2111, temp: 29, humidity: 57, cloudiness: 52, wind speed: 1.4
# 1: rafsanjan lat: 30.4067, temp: 26, humidity: 15, cloudiness: 79, wind speed: 3.61
# 1: kikwit lat: -5.041, temp: 25, humidity: 73, cloudiness: 51, wind speed: 1.27
# 1: mutsamudu lat: -5.041, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: presidencia roque saenz pena lat: -26.7852, temp: 21, humidity: 84, cloudiness: 100, wind speed: 0.89
# 1: vangaindrano lat: -23.35, temp: 22, humidity: 88, cloudiness: 51, wind speed: 1.05
# 1: cartagena lat: 10.3997, temp: 30, humidity: 79, cloudiness: 20, wind speed: 4.63
# 1: borgarnes lat: 64.5383, temp: 8, humidity: 81, cloudiness: 100, wind speed: 7.6
# 1: lentekhi lat: 42.7856, temp: 10, humidity: 99, cloudiness: 87, wind speed: 2.03
# 1: coquimbo lat: -29.9533, temp: 16, humidity: 82, cloudiness: 75, wind speed: 5.14
# 1: cap-aux-meules lat: 47.3821, temp: 8, humidity: 87, cloudiness: 99, wind speed: 9.77
# 1: saint-francois lat: 46.4154, temp: 17, humidity: 42, cloudiness: 0, wind speed: 3.09
# 1: parabel lat: 58.6978, temp: -6, humidity: 89, cloudiness: 8, wind speed: 0.33
# 1: crixas lat: -14.5489, temp: 30, humidity: 38, cloudiness: 5, wind speed: 1.85
# 1: lukulu lat: -14.3707, temp: 24, humidity: 47, cloudiness: 86, wind speed: 1.67
# 1: gracac lat: 44.3006, temp: 12, humidity: 87, cloudiness: 75, wind speed: 3.09
# 1: umzimvubu lat: 44.3006, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: ravar lat: 31.2656, temp: 26, humidity: 15, cloudiness: 31, wind speed: 1.85
# 1: marchena lat: 37.329, temp: 22, humidity: 53, cloudiness: 0, wind speed: 3.6
# 1: bronnoysund lat: 65.4625, temp: 3, humidity: 81, cloudiness: 40, wind speed: 5.66
# 1: maceio lat: -9.6658, temp: 30, humidity: 70, cloudiness: 20, wind speed: 4.63
# 1: portel lat: -1.9356, temp: 26, humidity: 87, cloudiness: 71, wind speed: 2.49
# 1: chapeltown lat: 53.4651, temp: 14, humidity: 33, cloudiness: 16, wind speed: 2.27
# 1: ust-tsilma lat: 65.441, temp: 4, humidity: 88, cloudiness: 100, wind speed: 4.22
# 1: asfi lat: 32.2994, temp: 19, humidity: 75, cloudiness: 86, wind speed: 7.76
# 1: autazes lat: -3.5797, temp: 29, humidity: 82, cloudiness: 81, wind speed: 1.4
# 1: adre lat: 13.4667, temp: 31, humidity: 11, cloudiness: 97, wind speed: 2.17
# 1: manakara lat: -22.1333, temp: 23, humidity: 85, cloudiness: 52, wind speed: 1.48
# 1: carutapera lat: -1.195, temp: 26, humidity: 90, cloudiness: 100, wind speed: 1.18
# 1: bosaso lat: 11.2842, temp: 28, humidity: 77, cloudiness: 1, wind speed: 0.54
# 1: san carlos del zulia lat: 9, temp: 33, humidity: 48, cloudiness: 6, wind speed: 0.82
# 1: chirongui lat: -12.9319, temp: 28, humidity: 74, cloudiness: 90, wind speed: 4.12
# 1: abu dhabi lat: 24.4667, temp: 29, humidity: 45, cloudiness: 0, wind speed: 2.57
# 1: bulawayo lat: -20.15, temp: 18, humidity: 47, cloudiness: 28, wind speed: 3.03
# 1: lasa lat: 46.6166, temp: 14, humidity: 46, cloudiness: 20, wind speed: 3.09
# 1: nieuw amsterdam lat: 5.8833, temp: 28, humidity: 70, cloudiness: 40, wind speed: 7.2
# 1: bonfim lat: 3.0833, temp: 34, humidity: 40, cloudiness: 70, wind speed: 3.53
# 1: balkanabat lat: 39.5108, temp: 26, humidity: 17, cloudiness: 67, wind speed: 8.27
# 1: porto franco lat: -6.3383, temp: 28, humidity: 76, cloudiness: 63, wind speed: 1.82
# 1: oeiras lat: -7.0253, temp: 29, humidity: 69, cloudiness: 46, wind speed: 1.73
# 1: bar harbor lat: 44.3876, temp: 3, humidity: 52, cloudiness: 90, wind speed: 3.6
# 1: khuzdar lat: 27.7384, temp: 24, humidity: 15, cloudiness: 0, wind speed: 2.15
# 1: vesele lat: 47.0148, temp: 9, humidity: 83, cloudiness: 81, wind speed: 3.74
# 1: kochevo lat: 59.5994, temp: 4, humidity: 97, cloudiness: 100, wind speed: 3.8
# 1: shache lat: 38.4167, temp: 13, humidity: 10, cloudiness: 22, wind speed: 5.99
# 1: cururupu lat: -1.8283, temp: 28, humidity: 74, cloudiness: 48, wind speed: 1.84
# 1: waw lat: 7.7029, temp: 26, humidity: 68, cloudiness: 98, wind speed: 3.39
# 1: point fortin lat: 10.1833, temp: 31, humidity: 39, cloudiness: 42, wind speed: 5.81
# 1: aksarka lat: 66.5606, temp: 3, humidity: 90, cloudiness: 100, wind speed: 7.25
# 1: mortka lat: 59.3322, temp: 8, humidity: 64, cloudiness: 71, wind speed: 5.18
# 1: kewanee lat: 41.2456, temp: 14, humidity: 40, cloudiness: 25, wind speed: 1.79
# 1: nordfjordeid lat: 61.9063, temp: 3, humidity: 65, cloudiness: 75, wind speed: 5.66
# 1: mabaruma lat: 8.2, temp: 31, humidity: 51, cloudiness: 76, wind speed: 3.89
# 1: kasongo-lunda lat: -6.4667, temp: 23, humidity: 94, cloudiness: 82, wind speed: 2.26
# 1: agas lat: 46.4833, temp: 12, humidity: 37, cloudiness: 89, wind speed: 2.54
# 1: porto novo lat: 6.4965, temp: 29, humidity: 84, cloudiness: 40, wind speed: 5.14
# 1: nahrin lat: 36.0649, temp: 12, humidity: 27, cloudiness: 0, wind speed: 1.3
# 1: varhaug lat: 58.6147, temp: 5, humidity: 72, cloudiness: 15, wind speed: 9.75
# 1: barkhan lat: 29.8977, temp: 24, humidity: 22, cloudiness: 0, wind speed: 2.26
# 1: novyy urengoy lat: 66.0833, temp: 1, humidity: 91, cloudiness: 100, wind speed: 7.63
# 1: menongue lat: -14.6585, temp: 22, humidity: 46, cloudiness: 68, wind speed: 1.55
# 1: richmond lat: 37.5538, temp: 13, humidity: 26, cloudiness: 75, wind speed: 6.69
# 1: oruro lat: -17.9833, temp: 17, humidity: 34, cloudiness: 20, wind speed: 3.09
# 1: san cosme y damian lat: -27.3167, temp: 28, humidity: 51, cloudiness: 0, wind speed: 2.06
# 1: kesinga lat: 20.2, temp: 32, humidity: 29, cloudiness: 88, wind speed: 1.98
# 1: kuznetsk lat: 53.1167, temp: 8, humidity: 80, cloudiness: 29, wind speed: 0.72
# 1: khaniotis lat: 39.9991, temp: 15, humidity: 86, cloudiness: 96, wind speed: 3.49
# 1: naantali lat: 60.4674, temp: 7, humidity: 61, cloudiness: 0, wind speed: 2.06
# 1: oskemen lat: 49.9565, temp: -2, humidity: 69, cloudiness: 77, wind speed: 4
# 1: kiruna lat: 67.8557, temp: -1, humidity: 55, cloudiness: 0, wind speed: 4.12
# 1: bastia lat: 42.6667, temp: 12, humidity: 67, cloudiness: 0, wind speed: 1.54
# 1: dalvik lat: 65.9702, temp: 5, humidity: 81, cloudiness: 0, wind speed: 4.12
# 1: dera ismail khan lat: 31.8327, temp: 24, humidity: 45, cloudiness: 25, wind speed: 8.86
# 1: korla lat: 41.7597, temp: 8, humidity: 50, cloudiness: 100, wind speed: 9.62
# 1: san lorenzo lat: -25.3333, temp: 20, humidity: 94, cloudiness: 90, wind speed: 5.66
# 1: chatra lat: 24.2167, temp: 27, humidity: 57, cloudiness: 75, wind speed: 1.25
# 1: beruwala lat: 6.4788, temp: 27, humidity: 83, cloudiness: 76, wind speed: 3.61
# 1: newtonmore lat: 57.066, temp: 9, humidity: 71, cloudiness: 20, wind speed: 3.6
# 1: bustonkala lat: 57.066, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: imperia lat: 43.9667, temp: 16, humidity: 41, cloudiness: 0, wind speed: 0.58
# 1: abiy adi lat: 43.9667, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: harqalah lat: 36.0303, temp: 17, humidity: 77, cloudiness: 40, wind speed: 7.72
# 1: antsohihy lat: -14.8796, temp: 24, humidity: 83, cloudiness: 100, wind speed: 0.32
# 1: synya lat: 65.3718, temp: 4, humidity: 96, cloudiness: 100, wind speed: 5.71
# 1: sao francisco do sul lat: -26.2433, temp: 23, humidity: 68, cloudiness: 75, wind speed: 2.06
# 1: keti bandar lat: 24.1447, temp: 28, humidity: 72, cloudiness: 0, wind speed: 7.64
# 1: vallenar lat: -28.5708, temp: 25, humidity: 28, cloudiness: 8, wind speed: 4.48
# 1: san andres lat: 12.5847, temp: 31, humidity: 62, cloudiness: 20, wind speed: 6.69
# 1: mizan teferi lat: 6.9833, temp: 17, humidity: 96, cloudiness: 100, wind speed: 1.09
# 1: savannah bight lat: 16.45, temp: 30, humidity: 55, cloudiness: 40, wind speed: 2.57
# 1: tulnici lat: 45.9167, temp: 13, humidity: 51, cloudiness: 0, wind speed: 1.54
# 1: rosh pinna lat: 32.9689, temp: 17, humidity: 68, cloudiness: 0, wind speed: 3.6
# 1: samoded lat: 63.6083, temp: 2, humidity: 86, cloudiness: 99, wind speed: 3.93
# 1: malakal lat: 9.5334, temp: 32, humidity: 37, cloudiness: 73, wind speed: 1
# 1: beroroha lat: -21.6667, temp: 26, humidity: 55, cloudiness: 13, wind speed: 2.9
# 1: khunti lat: 23.0833, temp: 26, humidity: 61, cloudiness: 40, wind speed: 1.77
# 1: aviles lat: 43.5547, temp: 17, humidity: 77, cloudiness: 0, wind speed: 1.03
# 1: phalaborwa lat: -23.943, temp: 22, humidity: 56, cloudiness: 61, wind speed: 1.54
# 1: constantine lat: 36.365, temp: 14, humidity: 77, cloudiness: 75, wind speed: 4.12
# 1: kidsgrove lat: 53.0869, temp: 12, humidity: 34, cloudiness: 42, wind speed: 1.79
# 1: bom jardim lat: -7.7958, temp: 30, humidity: 58, cloudiness: 75, wind speed: 4.63
# 1: moscow lat: 55.7522, temp: 10, humidity: 87, cloudiness: 0, wind speed: 4
# 1: iguai lat: -14.7564, temp: 25, humidity: 78, cloudiness: 99, wind speed: 1.1
# 1: opochka lat: 56.7105, temp: 4, humidity: 89, cloudiness: 97, wind speed: 2.22
# 1: urdoma lat: 61.7533, temp: 5, humidity: 87, cloudiness: 99, wind speed: 4.32
# 1: yangambi lat: 0.8102, temp: 23, humidity: 88, cloudiness: 85, wind speed: 1.43
# 1: moba lat: 33.2288, temp: 10, humidity: 96, cloudiness: 92, wind speed: 1.47
# 1: longford lat: 53.7333, temp: 12, humidity: 72, cloudiness: 23, wind speed: 5.17
# 1: formosa do rio preto lat: -11.0483, temp: 22, humidity: 92, cloudiness: 100, wind speed: 1.4
# 1: salta lat: -24.7859, temp: 24, humidity: 53, cloudiness: 40, wind speed: 3.6
# 1: mattru lat: 7.6244, temp: 30, humidity: 66, cloudiness: 98, wind speed: 2.86
# 1: pritzwalk lat: 53.1494, temp: 8, humidity: 62, cloudiness: 82, wind speed: 1.79
# 1: skjervoy lat: 70.0311, temp: 2, humidity: 55, cloudiness: 40, wind speed: 2.57
# 1: pucallpa lat: -8.3791, temp: 32, humidity: 58, cloudiness: 75, wind speed: 4.12
# 1: awbari lat: 26.5921, temp: 27, humidity: 27, cloudiness: 52, wind speed: 4.34
# 1: mwinilunga lat: -11.7358, temp: 20, humidity: 75, cloudiness: 100, wind speed: 1.73
# 1: turtkul lat: -11.7358, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: mumford lat: 5.2618, temp: 29, humidity: 77, cloudiness: 100, wind speed: 4.82
# 1: poltavka lat: 54.3663, temp: 2, humidity: 55, cloudiness: 1, wind speed: 3.75
# 1: karaul lat: 54.3663, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: yirol lat: 54.3663, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: buritizeiro lat: -17.3511, temp: 33, humidity: 21, cloudiness: 1, wind speed: 3.08
# 1: privas lat: 44.5833, temp: 19, humidity: 48, cloudiness: 20, wind speed: 4.12
# 1: zambezi lat: -13.5432, temp: 22, humidity: 59, cloudiness: 96, wind speed: 0.92
# 1: manresa lat: 41.725, temp: 15, humidity: 69, cloudiness: 100, wind speed: 1.79
# 1: panaba lat: 21.2833, temp: 31, humidity: 49, cloudiness: 40, wind speed: 2.63
# 1: inhambane lat: -23.865, temp: 21, humidity: 94, cloudiness: 20, wind speed: 3.68
# 1: chateauroux lat: 46.8167, temp: 19, humidity: 42, cloudiness: 0, wind speed: 5.14
# 1: belize lat: 17.25, temp: 31, humidity: 58, cloudiness: 40, wind speed: 4.12
# 1: lokosovo lat: 61.1333, temp: -1, humidity: 81, cloudiness: 29, wind speed: 4.23
# 1: kargasok lat: 59.0556, temp: -6, humidity: 87, cloudiness: 7, wind speed: 1.67
# 1: norashen lat: 39.9996, temp: 16, humidity: 31, cloudiness: 95, wind speed: 1.03
# 1: platanos lat: 37.6667, temp: 12, humidity: 67, cloudiness: 40, wind speed: 2.29
# 1: dhar lat: 22.6, temp: 25, humidity: 22, cloudiness: 45, wind speed: 1.88
# 1: gewane lat: 10.1664, temp: 33, humidity: 21, cloudiness: 72, wind speed: 5.54
# 1: kulhudhuffushi lat: 6.6221, temp: 29, humidity: 72, cloudiness: 18, wind speed: 3.89
# 1: sao felix do xingu lat: -6.6447, temp: 28, humidity: 80, cloudiness: 68, wind speed: 1.28
# 1: tsaratanana lat: -16.7833, temp: 23, humidity: 78, cloudiness: 76, wind speed: 3.8
# 1: mto wa mbu lat: -3.35, temp: 21, humidity: 78, cloudiness: 99, wind speed: 0.53
# 1: bermeo lat: 43.4209, temp: 20, humidity: 46, cloudiness: 20, wind speed: 3.6
# 1: norre alslev lat: 54.8978, temp: 8, humidity: 60, cloudiness: 22, wind speed: 2.24
# 1: bajil lat: 15.0584, temp: 32, humidity: 37, cloudiness: 1, wind speed: 0.55
# 1: yambio lat: 4.5721, temp: 21, humidity: 93, cloudiness: 95, wind speed: 1.3
# 1: benghazi lat: 32.1167, temp: 21, humidity: 50, cloudiness: 98, wind speed: 1.42
# 1: sakakah lat: 29.9697, temp: 31, humidity: 13, cloudiness: 40, wind speed: 3.6
# 1: noyabrsk lat: 63.1994, temp: -2, humidity: 79, cloudiness: 63, wind speed: 6.87
# 1: damavand lat: 35.7178, temp: 28, humidity: 15, cloudiness: 75, wind speed: 2.06
# 1: anloga lat: 5.7947, temp: 30, humidity: 70, cloudiness: 20, wind speed: 5.14
# 1: priverno lat: 41.4691, temp: 12, humidity: 87, cloudiness: 75, wind speed: 1.54
# 1: tunduru lat: 41.4691, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan
# 1: chimoio lat: -19.1164, temp: 17, humidity: 100, cloudiness: 20, wind speed: 2.06
# 1: jackson lat: 42.4165, temp: 16, humidity: 39, cloudiness: 1, wind speed: 2.57
# 1: umkomaas lat: -30.2067, temp: 19, humidity: 91, cloudiness: 76, wind speed: 0.45
# 1: kadoma lat: 34.7333, temp: 11, humidity: 38, cloudiness: 77, wind speed: 3.08
# 1: kapra lat: 17.4846, temp: 25, humidity: 61, cloudiness: 75, wind speed: 3.67
# 1: esil lat: 51.9556, temp: 7, humidity: 44, cloudiness: 100, wind speed: 6.9
# 1: finnsnes lat: 69.2296, temp: 0, humidity: 93, cloudiness: 40, wind speed: 1.54
# 1: hemsedal lat: 60.8629, temp: -2, humidity: 51, cloudiness: 17, wind speed: 1.34
# 1: aberystwyth lat: 52.4155, temp: 13, humidity: 43, cloudiness: 2, wind speed: 1.34
# 1: altay lat: 47.8667, temp: -2, humidity: 47, cloudiness: 100, wind speed: 1.81
# 1: taguatinga lat: -12.3857, temp: 26, humidity: 76, cloudiness: 67, wind speed: 2.09
# 1: barbar lat: -12.3857, temp: nan, humidity: nan, cloudiness: nan, wind speed: nan

# %%
lat_vs_temp_df = pd.DataFrame({"City" : clean_initial_city_list_df['Cities'],
                             "Latitude": lats,
                               "Degrees From Equator": list(map(abs, lats)),
                               "Temperature" : temps,
                               "Humidity" : humids,
                               "Cloudiness" : cloudies,
                               "Wind Speed" : wind_speeds
                              })
lat_vs_temp_df
# Out:
#               City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0            debno   52.7390               52.7390          7.0      68.0
# 1         orgovany   46.7509               46.7509         12.0      76.0
# 2          bubaque   11.2833               11.2833         26.0      68.0
# 3         sabzevar   36.2126               36.2126         22.0      27.0
# 4    teofilo otoni  -17.8575               17.8575         27.0      58.0
# ..             ...       ...                   ...          ...       ...
# 876       hemsedal   60.8629               60.8629         -2.0      51.0
# 877    aberystwyth   52.4155               52.4155         13.0      43.0
# 878          altay   47.8667               47.8667         -2.0      47.0
# 879     taguatinga  -12.3857               12.3857         26.0      76.0
# 880         barbar  -12.3857               12.3857          NaN       NaN
#
#      Cloudiness  Wind Speed
# 0          51.0        0.89
# 1           0.0        3.09
# 2          48.0        7.50
# 3           7.0        5.48
# 4          28.0        0.84
# ..          ...         ...
# 876        17.0        1.34
# 877         2.0        1.34
# 878       100.0        1.81
# 879        67.0        2.09
# 880         NaN         NaN
#
# [881 rows x 7 columns]

# %%
clean_lat_vs_temp_df = lat_vs_temp_df.dropna(how='any', axis=0)

clean_lat_vs_temp_df= clean_lat_vs_temp_df.drop_duplicates(subset ="City",
                     keep = 'first').reset_index(drop=True)

clean_lat_vs_temp_df
# Out:
#               City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0            debno   52.7390               52.7390          7.0      68.0
# 1         orgovany   46.7509               46.7509         12.0      76.0
# 2          bubaque   11.2833               11.2833         26.0      68.0
# 3         sabzevar   36.2126               36.2126         22.0      27.0
# 4    teofilo otoni  -17.8575               17.8575         27.0      58.0
# ..             ...       ...                   ...          ...       ...
# 816       finnsnes   69.2296               69.2296          0.0      93.0
# 817       hemsedal   60.8629               60.8629         -2.0      51.0
# 818    aberystwyth   52.4155               52.4155         13.0      43.0
# 819          altay   47.8667               47.8667         -2.0      47.0
# 820     taguatinga  -12.3857               12.3857         26.0      76.0
#
#      Cloudiness  Wind Speed
# 0          51.0        0.89
# 1           0.0        3.09
# 2          48.0        7.50
# 3           7.0        5.48
# 4          28.0        0.84
# ..          ...         ...
# 816        40.0        1.54
# 817        17.0        1.34
# 818         2.0        1.34
# 819       100.0        1.81
# 820        67.0        2.09
#
# [821 rows x 7 columns]

# %%
# Set up list of variables to compare with latitude

master_plot_list = ["Temperature", "Humidity", "Cloudiness", "Wind Speed"]

# %%
                # PLOTTING WEATHER CONDITIONS VS. LATITUDE USING A FOR LOOP

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, sharey='row', figsize=(12,10))
#fig = plt.figure()
#fig.set_size_inches() 
fig.text(-.02, 0.5, "Distance from Equator in Degrees", va='center', rotation='vertical', fontsize=20)

plot_list = [ax0, ax1, ax2, ax3]
fig.suptitle('WEATHER CONDITIONS VS LATITUDE', ha='center') 
#ax0.set_ylabel("Distance from Equator in Degrees")

axs_toplot ={}

for i in range (4):   

    x_axis_name = master_plot_list[i]                           # Set name of x axis for the sake of labels
    x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
    y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

    slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
    regress_values = x_axis * slope + intercept                 # Calculate regression values
              
    plot_list[i].set_xlabel(f"{x_axis_name}")                   

    plot_list[i].set_title(f"{x_axis_name} vs. Latitude")  
    
    r = round(stats.pearsonr(x_axis, y_axis)[0],2)
    if abs(r) >=.8 : r_label = "Very Strong"
    elif abs(r) >=.6 : r_label = "Strong"
    elif abs(r) >= .4 : r_label = "Moderate"
    elif abs(r) >= .2 : r_label = "Low"
    else: r_label = "Negligible"

    plot_list[i].scatter(x_axis, y_axis, facecolors="darkred",  alpha=.5, 
                         label=f"{x_axis_name} r = {r} \nCorrelation is {r_label}")                                                 

    plot_list[i].plot(x_axis, regress_values, color="steelblue")         # Plot the regression line
    plot_list[i].legend()
    
fig.tight_layout()

plt.show()

# %% [markdown]
#                                                     CONCLUSIONS
# As you can see from the charts above, the correlation between temperature and distance from the equator (i.e., positive and negative latitudes) is very strong, supporting the assertion that climates get warmer as you get closer to the equator.
#
# All other weather conditions (humidity, cloudiness and wind speed) have negligible correlations.

# %%
north_hem_df = clean_lat_vs_temp_df.loc[clean_lat_vs_temp_df['Latitude'] > 0, ].reset_index(drop=True)
north_hem_df
# Out:
#             City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0          debno   52.7390               52.7390          7.0      68.0
# 1       orgovany   46.7509               46.7509         12.0      76.0
# 2        bubaque   11.2833               11.2833         26.0      68.0
# 3       sabzevar   36.2126               36.2126         22.0      27.0
# 4            sur   22.5667               22.5667         31.0      31.0
# ..           ...       ...                   ...          ...       ...
# 571         esil   51.9556               51.9556          7.0      44.0
# 572     finnsnes   69.2296               69.2296          0.0      93.0
# 573     hemsedal   60.8629               60.8629         -2.0      51.0
# 574  aberystwyth   52.4155               52.4155         13.0      43.0
# 575        altay   47.8667               47.8667         -2.0      47.0
#
#      Cloudiness  Wind Speed
# 0          51.0        0.89
# 1           0.0        3.09
# 2          48.0        7.50
# 3           7.0        5.48
# 4          32.0        4.02
# ..          ...         ...
# 571       100.0        6.90
# 572        40.0        1.54
# 573        17.0        1.34
# 574         2.0        1.34
# 575       100.0        1.81
#
# [576 rows x 7 columns]

# %%
south_hem_df = clean_lat_vs_temp_df.loc[clean_lat_vs_temp_df['Latitude'] <= 0, ].reset_index(drop=True)
south_hem_df
# Out:
#               City  Latitude  Degrees From Equator  Temperature  Humidity  \
# 0    teofilo otoni  -17.8575               17.8575         27.0      58.0
# 1          ushuaia  -54.8000               54.8000          8.0      87.0
# 2       bredasdorp  -34.5322               34.5322         15.0      94.0
# 3        hithadhoo   -0.6000                0.6000         28.0      72.0
# 4           castro  -24.7911               24.7911         18.0      71.0
# ..             ...       ...                   ...          ...       ...
# 240    tsaratanana  -16.7833               16.7833         23.0      78.0
# 241     mto wa mbu   -3.3500                3.3500         21.0      78.0
# 242        chimoio  -19.1164               19.1164         17.0     100.0
# 243       umkomaas  -30.2067               30.2067         19.0      91.0
# 244     taguatinga  -12.3857               12.3857         26.0      76.0
#
#      Cloudiness  Wind Speed
# 0          28.0        0.84
# 1          90.0        1.54
# 2           6.0        2.57
# 3          74.0        3.45
# 4          85.0        0.80
# ..          ...         ...
# 240        76.0        3.80
# 241        99.0        0.53
# 242        20.0        2.06
# 243        76.0        0.45
# 244        67.0        2.09
#
# [245 rows x 7 columns]

# %%
        # PLOTTING WEATHER CONDITIONS BY HEMISPHERE VS. LATITUDE USING A FOR LOOP

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, sharey='row', figsize=(12,10))
#fig = plt.figure()
#fig.set_size_inches() 
fig.text(-.02, 0.5, "Distance from Equator in Degrees", va='center', rotation='vertical', fontsize=20)

plot_list = [ax0, ax1, ax2, ax3]
fig.suptitle('WEATHER CONDITIONS VS LATITUDE', ha='center') 
#ax0.set_ylabel("Distance from Equator in Degrees")

axs_toplot ={}

for i in range (4):   

        # Northern Hemisphere
    north_x_axis_name = master_plot_list[i]                           # Set name of x axis for the sake of labels
    north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
    north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

    slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
    north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    north_r = round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)
    if abs(north_r) >=.8 : north_r_label = "Very Strong"
    elif abs(north_r) >=.6 : north_r_label = "Strong"
    elif abs(north_r) >= .4 : north_r_label = "Moderate"
    elif abs(north_r) >= .2 : north_r_label = "Low"
    else: north_r_label = "Negligible"
    
    
        # Southern Hemisphere
    south_x_axis_name = master_plot_list[i]                           # Set name of x axis for the sake of labels
    south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
    south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 
    
    slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
    south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values   
    
    south_r = round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)
    if abs(south_r) >= .8 : south_r_label = "Very Strong"
    elif abs(south_r) >= .6 : south_r_label = "Strong"
    elif abs(south_r) >= .4 : south_r_label = "Moderate"
    elif abs(south_r) >= .2 : south_r_label = "Low"
    else: south_r_label = "Negligible"  
    
    
    # Formatting
    plot_list[i].set_xlabel(f"{x_axis_name}")                   

    plot_list[i].set_title(f"{x_axis_name} vs. Latitude")  
     
        
    # lotting
        # Northern Hemisphere
    plot_list[i].scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5, 
                         label=f"N. Hemisphere {north_x_axis_name} r = {north_r} \nCorrelation is {north_r_label}")                                                 

    plot_list[i].plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line
    
        # Southern Hemisphere
    plot_list[i].scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5,
                         label=f"S. Hemisphere {south_x_axis_name} r = {south_r} \nCorrelation is {south_r_label}")                                                 

    plot_list[i].plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line    
       
    plot_list[i].legend(fontsize=10)
    
fig.tight_layout()
plt.show()

# %% [markdown]
# This analysis by hemisphere doesn't change the initial results. Temperature is still the only weather variable that has a strong correlation to latitude, although the correlation is even stronger in southern hemisphere comparted to the north.
#
# The only other observable difference is that the Wind speed correlation in the Northern Hemisphere is low, versus negligable in the Southern Hemisphere

# %%
                                    # TEMPERATURE VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[0]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[0]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

plt.figure(figsize=(10, 7))                                       # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min()-2, north_x_axis.max()+2)              # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
     
# Plotting 

    # Northern Hemisphere
plt.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5) # Plot the scatter chart
plt.annotate(f"{north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}", # Plot the correlation coeficient
             (-7,26), fontsize=15, color="darkred")                                                   

plt.plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line

    # Southern Hemisphere
plt.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=1) # Plot the scatter chart
plt.annotate(f"{south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}", # Plot the correlation coeficient
             (-7,21), fontsize=15, color="steelblue")                                                   

plt.plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line



plt.show()

# %%
                                    # HUMIDITY VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[1]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[1]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

fig, ax = plt.subplots()                                          # Set up subplots to make the legend easier to create
fig.set_size_inches(10, 7)                                        # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min(), north_x_axis.max())                    # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
# Plotting 

    # Northern Hemisphere
ax.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5, label='Northern Hemisphere') # Plot the scatter chart
ax.annotate(f"{north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,26), fontsize=15, color="darkred")                                                   

ax.plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line

    # Southern Hemisphere
ax.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5, label='Southern Hemisphere') # Plot the scatter chart
ax.annotate(f"{south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,21), fontsize=15, color="steelblue")                                                   

ax.plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line

plt.legend()                                                           # Add the legend
plt.show()

# %%
                                    # CLOUDINESS VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[2]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[2]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

fig, ax = plt.subplots()                                          # Set up subplots to make the legend easier to create
fig.set_size_inches(10, 7)                                        # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min(), north_x_axis.max())                    # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
# Plotting 

    # Northern Hemisphere
ax.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5,  # Plot the scatter chart
           label=f"Northern Hemisphere: {north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}")                                                  

ax.plot(north_x_axis, north_regress_values, color="darkred")       # Plot the regression line

    # Southern Hemisphere
ax.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5, # Plot the scatter chart
           label=f"Southern Hemisphere: {south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}")                                                 

ax.plot(south_x_axis, south_regress_values, color="steelblue")     # Plot the regression line

plt.legend()                                                       # Add the legend
plt.show()

# %%
                                    # WIND SPEED VS LATITUDE BY HEMISPHERE
# Data & calculations

    # Northern Hemisphere
north_x_axis_name = master_plot_list[3]                           # Set name of x axis for the sake of labels
north_x_axis = north_hem_df[north_x_axis_name]                          # Set up x axis values 
north_y_axis = north_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(north_x_axis, north_y_axis)  # Get elements of regression equation
north_regress_values = north_x_axis * slope + intercept                 # Calculate regression values

    # Southern Hemisphere
south_x_axis_name = master_plot_list[3]                           # Set name of x axis for the sake of labels
south_x_axis = south_hem_df[south_x_axis_name]                          # Set up x axis values 
south_y_axis = south_hem_df["Degrees From Equator"]               # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(south_x_axis, south_y_axis)  # Get elements of regression equation
south_regress_values = south_x_axis * slope + intercept                 # Calculate regression values

# Formating

fig, ax = plt.subplots()                                          # Set up subplots to make the legend easier to create
fig.set_size_inches(10, 7)                                        # Set up figure size a little larger than default                    
plt.xlabel(f"{north_x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")                    # Set y axis label
plt.title(f"{north_x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(north_x_axis.min(), north_x_axis.max())                    # Give chart some white space at margins
plt.ylim(north_y_axis.min()-5, north_y_axis.max()+5)
plt.xticks(range(int(north_x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(north_x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(north_y_axis.min()-2),                       # Set up ticks on the y axis
                 int(north_y_axis.max())+5,5), rotation=0 )
# Plotting 

    # Northern Hemisphere
ax.scatter(north_x_axis, north_y_axis, facecolors="darkred",  alpha=.5, label='Northern Hemisphere') # Plot the scatter chart
ax.annotate(f"{north_x_axis_name} r = {round(stats.pearsonr(north_x_axis, north_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,26), fontsize=15, color="darkred")                                                   

ax.plot(north_x_axis, north_regress_values, color="darkred")         # Plot the regression line

    # Southern Hemisphere
ax.scatter(south_x_axis, south_y_axis, facecolors="steelblue",  alpha=.5, label='Southern Hemisphere') # Plot the scatter chart
ax.annotate(f"{south_x_axis_name} r = {round(stats.pearsonr(south_x_axis, south_y_axis)[0],2)}", # Plot the correlation coeficient
             (9,21), fontsize=15, color="steelblue")                                                   

ax.plot(south_x_axis, south_regress_values, color="steelblue")         # Plot the regression line

plt.legend()                                                           # Add the legend
plt.show()

# %%
                                            # TEMPERATURE VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[0]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating

plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                    
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (-7,21), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()

# %%
                                            # HUMIDITY VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[1]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating
plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                   
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (13,76), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()

# %%
                                        # CLOUDINESS VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[2]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating
 
plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                   
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (3,76), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()

# %%
                                            # WIND SPEED VS LATITUDE
# Data & calculations

x_axis_name = master_plot_list[3]                           # Set name of x axis for the sake of labels
x_axis = clean_lat_vs_temp_df[x_axis_name]                  # Set up x axis values 
y_axis = clean_lat_vs_temp_df["Degrees From Equator"]       # Set up y axis values 

slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_axis, y_axis)  # Get elements of regression equation
regress_values = x_axis * slope + intercept                 # Calculate regression values

# Formating

plt.figure(figsize=(10, 7))                                 # Set up figure size a little larger than default                    
plt.xlabel(f"{x_axis_name}")                                # Set x axis label                              
plt.ylabel("Distance from Equator in Degrees")              # Set y axis label
plt.title(f"{x_axis_name} vs Latitude")                     # Set chart title
plt.xlim(x_axis.min()-2, x_axis.max()+2)                    # Give chart some white space at margins
plt.ylim(y_axis.min()-5, y_axis.max()+5)
plt.xticks(range(int(x_axis.min()-2),                       # Set up ticks on the x axis 
                 int(x_axis.max())+5,5), rotation=0 )  
plt.yticks(range(int(y_axis.min()-2),                       # Set up ticks on the y axis
                 int(y_axis.max())+5,5), rotation=0 )
     
# Plotting 

plt.scatter(x_axis, y_axis, facecolors="darkred",  alpha=1) # Plot the scatter chart

plt.annotate(f"{x_axis_name} r = {round(stats.pearsonr(x_axis, y_axis)[0],2)}", # Plot the correlation coeficient
             (9,21), fontsize=15, color="steelblue")                                                   

plt.plot(x_axis, regress_values, color="steelblue")         # Plot the regression line

plt.show()
